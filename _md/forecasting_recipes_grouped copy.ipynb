# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/matthewdeane/Documents/Data%20Science/python/_projects/py-tidymodels/_md
# ERROR: file:///Users/matthewdeane/Documents/Data%20Science/python/_projects/py-tidymodels/_md does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# py-tidymodels imports
from py_workflows import workflow
from py_parsnip import linear_reg, rand_forest, boost_tree
from py_rsample import initial_split, training, testing
from py_yardstick import metric_set, rmse, mae, r_squared

# Recipe imports
from py_recipes import recipe
from py_recipes.selectors import (
    all_numeric, all_nominal, all_predictors, all_outcomes,
    all_numeric_predictors, all_nominal_predictors,
    contains, starts_with, ends_with, matches  # ← These are now available
)

from py_visualize import plot_forecast, plot_residuals

# Set random seed for reproducibility
np.random.seed(42)

# %% [markdown]
# # Recipes Demonstration Notebook
#
# This notebook demonstrates various preprocessing techniques using py-recipes with the same forecasting data.
#
# ## Contents:
# 1. Data loading and splitting
# 2. Basic recipes
# 3. Feature engineering recipes
# 4. Model comparison with different recipes
# 5. Advanced recipe patterns

# %% [markdown]
# # 1. Import Data

# %%
# import raw data
raw_data = pd.read_csv('__data/refinery_margins.csv')

# %%
df = raw_data

# set date as index
#df = raw_data.set_index('date')

# convert date to datetime
df['date'] = pd.to_datetime(df['date'])
display(df)
# Out:
#            date             country  refinery_kbd  brent  dubai    wti  \
# 0    2006-01-01             Algeria      450.0000  63.57  58.31  65.48
# 1    2006-01-01             Denmark      172.9948  63.57  58.31  65.48
# 2    2006-01-01             Germany     2270.5419  63.57  58.31  65.48
# 3    2006-01-01               Italy     1859.7058  63.57  58.31  65.48
# 4    2006-01-01         Netherlands      907.5555  63.57  58.31  65.48
# ...         ...                 ...           ...    ...    ...    ...
# 1915 2021-12-01              Norway      224.7000  74.31  72.76  71.53
# 1916 2021-12-01             Romania      226.6026  74.31  72.76  71.53
# 1917 2021-12-01  Russian Federation     5924.5209  74.31  72.76  71.53
# 1918 2021-12-01              Turkey      773.1726  74.31  72.76  71.53
# 1919 2021-12-01      United Kingdom     1031.5206  74.31  72.76  71.53
#
#       brent_cracking_nw_europe  brent_hydroskimming_nw_europe  \
# 0                         3.12                          -2.51
# 1                         3.12                          -2.51
# 2                         3.12                          -2.51
# 3                         3.12                          -2.51
# 4                         3.12                          -2.51
# ...                        ...                            ...
# 1915                      5.11                           2.89
# 1916                      5.11                           2.89
# 1917                      5.11                           2.89
# 1918                      5.11                           2.89
# 1919                      5.11                           2.89
#
#       urals_cracking_nw_europe  urals_hydroskimming_nw_europe  \
# 0                         5.30                          -2.18
# 1                         5.30                          -2.18
# 2                         5.30                          -2.18
# 3                         5.30                          -2.18
# 4                         5.30                          -2.18
# ...                        ...                            ...
# 1915                      5.14                           0.53
# 1916                      5.14                           0.53
# 1917                      5.14                           0.53
# 1918                      5.14                           0.53
# 1919                      5.14                           0.53
#
#       es_sider_cracking_med  es_sider_hydroskimming_med  urals_cracking_med  \
# 0                      4.81                       -0.17                6.80
# 1                      4.81                       -0.17                6.80
# 2                      4.81                       -0.17                6.80
# 3                      4.81                       -0.17                6.80
# 4                      4.81                       -0.17                6.80
# ...                     ...                         ...                 ...
# 1915                   6.52                        4.58                5.31
# 1916                   6.52                        4.58                5.31
# 1917                   6.52                        4.58                5.31
# 1918                   6.52                        4.58                5.31
# 1919                   6.52                        4.58                5.31
#
#       urals_hydroskimming_med  dubai_cracking_singapore  \
# 0                       -1.52                      2.47
# 1                       -1.52                      2.47
# 2                       -1.52                      2.47
# 3                       -1.52                      2.47
# 4                       -1.52                      2.47
# ...                       ...                       ...
# 1915                    -0.31                      8.24
# 1916                    -0.31                      8.24
# 1917                    -0.31                      8.24
# 1918                    -0.31                      8.24
# 1919                    -0.31                      8.24
#
#       dubai_hydroskimming_singapore  tapis_hydroskimming_singapore  \
# 0                             -3.16                          -1.79
# 1                             -3.16                          -1.79
# 2                             -3.16                          -1.79
# 3                             -3.16                          -1.79
# 4                             -3.16                          -1.79
# ...                             ...                            ...
# 1915                          -1.12                           3.23
# 1916                          -1.12                           3.23
# 1917                          -1.12                           3.23
# 1918                          -1.12                           3.23
# 1919                          -1.12                           3.23
#
#       x50_50_hls_lls_cracking_usgc  x30_70_wcs_bakken_cracking_usmc  \
# 0                            -5.68                             0.38
# 1                            -5.68                             0.38
# 2                            -5.68                             0.38
# 3                            -5.68                             0.38
# 4                            -5.68                             0.38
# ...                            ...                              ...
# 1915                          3.45                            10.51
# 1916                          3.45                            10.51
# 1917                          3.45                            10.51
# 1918                          3.45                            10.51
# 1919                          3.45                            10.51
#
#       bakken_coking_usmc
# 0                   2.57
# 1                   2.57
# 2                   2.57
# 3                   2.57
# 4                   2.57
# ...                  ...
# 1915               11.87
# 1916               11.87
# 1917               11.87
# 1918               11.87
# 1919               11.87
#
# [1920 rows x 20 columns]

# %% [markdown]
# # 2. Train/Test Split

# %%
# Create train/test split
split = initial_split(df, prop=0.75, seed=123)
train_data = training(split)
test_data = testing(split)

print(f"Training set: {train_data.shape[0]} rows")
print(f"Test set: {test_data.shape[0]} rows")
display(train_data.head(10))
display(test_data.tail(10))
# Out:
# Training set: 1440 rows
# Test set: 480 rows
#         date             country  refinery_kbd  brent  dubai    wti  \
# 0 2006-01-01             Algeria      450.0000  63.57  58.31  65.48
# 1 2006-01-01             Denmark      172.9948  63.57  58.31  65.48
# 2 2006-01-01             Germany     2270.5419  63.57  58.31  65.48
# 3 2006-01-01               Italy     1859.7058  63.57  58.31  65.48
# 4 2006-01-01         Netherlands      907.5555  63.57  58.31  65.48
# 5 2006-01-01              Norway      316.9961  63.57  58.31  65.48
# 6 2006-01-01             Romania      330.4621  63.57  58.31  65.48
# 7 2006-01-01  Russian Federation     4319.2710  63.57  58.31  65.48
# 8 2006-01-01              Turkey      437.9177  63.57  58.31  65.48
# 9 2006-01-01      United Kingdom     1608.6955  63.57  58.31  65.48
#
#    brent_cracking_nw_europe  brent_hydroskimming_nw_europe  \
# 0                      3.12                          -2.51
# 1                      3.12                          -2.51
# 2                      3.12                          -2.51
# 3                      3.12                          -2.51
# 4                      3.12                          -2.51
# 5                      3.12                          -2.51
# 6                      3.12                          -2.51
# 7                      3.12                          -2.51
# 8                      3.12                          -2.51
# 9                      3.12                          -2.51
#
#    urals_cracking_nw_europe  urals_hydroskimming_nw_europe  \
# 0                       5.3                          -2.18
# 1                       5.3                          -2.18
# 2                       5.3                          -2.18
# 3                       5.3                          -2.18
# 4                       5.3                          -2.18
# 5                       5.3                          -2.18
# 6                       5.3                          -2.18
# 7                       5.3                          -2.18
# 8                       5.3                          -2.18
# 9                       5.3                          -2.18
#
#    es_sider_cracking_med  es_sider_hydroskimming_med  urals_cracking_med  \
# 0                   4.81                       -0.17                 6.8
# 1                   4.81                       -0.17                 6.8
# 2                   4.81                       -0.17                 6.8
# 3                   4.81                       -0.17                 6.8
# 4                   4.81                       -0.17                 6.8
# 5                   4.81                       -0.17                 6.8
# 6                   4.81                       -0.17                 6.8
# 7                   4.81                       -0.17                 6.8
# 8                   4.81                       -0.17                 6.8
# 9                   4.81                       -0.17                 6.8
#
#    urals_hydroskimming_med  dubai_cracking_singapore  \
# 0                    -1.52                      2.47
# 1                    -1.52                      2.47
# 2                    -1.52                      2.47
# 3                    -1.52                      2.47
# 4                    -1.52                      2.47
# 5                    -1.52                      2.47
# 6                    -1.52                      2.47
# 7                    -1.52                      2.47
# 8                    -1.52                      2.47
# 9                    -1.52                      2.47
#
#    dubai_hydroskimming_singapore  tapis_hydroskimming_singapore  \
# 0                          -3.16                          -1.79
# 1                          -3.16                          -1.79
# 2                          -3.16                          -1.79
# 3                          -3.16                          -1.79
# 4                          -3.16                          -1.79
# 5                          -3.16                          -1.79
# 6                          -3.16                          -1.79
# 7                          -3.16                          -1.79
# 8                          -3.16                          -1.79
# 9                          -3.16                          -1.79
#
#    x50_50_hls_lls_cracking_usgc  x30_70_wcs_bakken_cracking_usmc  \
# 0                         -5.68                             0.38
# 1                         -5.68                             0.38
# 2                         -5.68                             0.38
# 3                         -5.68                             0.38
# 4                         -5.68                             0.38
# 5                         -5.68                             0.38
# 6                         -5.68                             0.38
# 7                         -5.68                             0.38
# 8                         -5.68                             0.38
# 9                         -5.68                             0.38
#
#    bakken_coking_usmc
# 0                2.57
# 1                2.57
# 2                2.57
# 3                2.57
# 4                2.57
# 5                2.57
# 6                2.57
# 7                2.57
# 8                2.57
# 9                2.57
#           date             country  refinery_kbd  brent  dubai    wti  \
# 470 2021-12-01             Algeria      557.0000  74.31  72.76  71.53
# 471 2021-12-01             Denmark      156.5652  74.31  72.76  71.53
# 472 2021-12-01             Germany     1898.9548  74.31  72.76  71.53
# 473 2021-12-01               Italy     1246.4516  74.31  72.76  71.53
# 474 2021-12-01         Netherlands      951.1219  74.31  72.76  71.53
# 475 2021-12-01              Norway      224.7000  74.31  72.76  71.53
# 476 2021-12-01             Romania      226.6026  74.31  72.76  71.53
# 477 2021-12-01  Russian Federation     5924.5209  74.31  72.76  71.53
# 478 2021-12-01              Turkey      773.1726  74.31  72.76  71.53
# 479 2021-12-01      United Kingdom     1031.5206  74.31  72.76  71.53
#
#      brent_cracking_nw_europe  brent_hydroskimming_nw_europe  \
# 470                      5.11                           2.89
# 471                      5.11                           2.89
# 472                      5.11                           2.89
# 473                      5.11                           2.89
# 474                      5.11                           2.89
# 475                      5.11                           2.89
# 476                      5.11                           2.89
# 477                      5.11                           2.89
# 478                      5.11                           2.89
# 479                      5.11                           2.89
#
#      urals_cracking_nw_europe  urals_hydroskimming_nw_europe  \
# 470                      5.14                           0.53
# 471                      5.14                           0.53
# 472                      5.14                           0.53
# 473                      5.14                           0.53
# 474                      5.14                           0.53
# 475                      5.14                           0.53
# 476                      5.14                           0.53
# 477                      5.14                           0.53
# 478                      5.14                           0.53
# 479                      5.14                           0.53
#
#      es_sider_cracking_med  es_sider_hydroskimming_med  urals_cracking_med  \
# 470                   6.52                        4.58                5.31
# 471                   6.52                        4.58                5.31
# 472                   6.52                        4.58                5.31
# 473                   6.52                        4.58                5.31
# 474                   6.52                        4.58                5.31
# 475                   6.52                        4.58                5.31
# 476                   6.52                        4.58                5.31
# 477                   6.52                        4.58                5.31
# 478                   6.52                        4.58                5.31
# 479                   6.52                        4.58                5.31
#
#      urals_hydroskimming_med  dubai_cracking_singapore  \
# 470                    -0.31                      8.24
# 471                    -0.31                      8.24
# 472                    -0.31                      8.24
# 473                    -0.31                      8.24
# 474                    -0.31                      8.24
# 475                    -0.31                      8.24
# 476                    -0.31                      8.24
# 477                    -0.31                      8.24
# 478                    -0.31                      8.24
# 479                    -0.31                      8.24
#
#      dubai_hydroskimming_singapore  tapis_hydroskimming_singapore  \
# 470                          -1.12                           3.23
# 471                          -1.12                           3.23
# 472                          -1.12                           3.23
# 473                          -1.12                           3.23
# 474                          -1.12                           3.23
# 475                          -1.12                           3.23
# 476                          -1.12                           3.23
# 477                          -1.12                           3.23
# 478                          -1.12                           3.23
# 479                          -1.12                           3.23
#
#      x50_50_hls_lls_cracking_usgc  x30_70_wcs_bakken_cracking_usmc  \
# 470                          3.45                            10.51
# 471                          3.45                            10.51
# 472                          3.45                            10.51
# 473                          3.45                            10.51
# 474                          3.45                            10.51
# 475                          3.45                            10.51
# 476                          3.45                            10.51
# 477                          3.45                            10.51
# 478                          3.45                            10.51
# 479                          3.45                            10.51
#
#      bakken_coking_usmc
# 470               11.87
# 471               11.87
# 472               11.87
# 473               11.87
# 474               11.87
# 475               11.87
# 476               11.87
# 477               11.87
# 478               11.87
# 479               11.87

# %% [markdown]
# # 3. Define Formula
#
# Using dot notation to include all columns except target and date.

# %%
# Define formulas for nested vs global modeling
FORMULA_STR = "refinery_kbd ~ ."  # Dot notation - excludes date automatically
# FORMULA_GLOBAL = "refinery_kbd ~ ."  # Same formula, but fit_global adds 'country'

# Show group structure
print("=== Panel Data Structure ===")
print(f"Total countries: {train_data['country'].nunique()}")
print(f"Countries: {sorted(train_data['country'].unique())}")
print(f"\nObservations per country (train):")
print(train_data.groupby('country').size())
print(f"\nDate range per country (train):")
print(train_data.groupby('country')['date'].agg(['min', 'max']))
# Out:
# === Panel Data Structure ===
# Total countries: 10
# Countries: ['Algeria', 'Denmark', 'Germany', 'Italy', 'Netherlands', 'Norway', 'Romania', 'Russian Federation', 'Turkey', 'United Kingdom']
#
# Observations per country (train):
# country
# Algeria               144
# Denmark               144
# Germany               144
# Italy                 144
# Netherlands           144
# Norway                144
# Romania               144
# Russian Federation    144
# Turkey                144
# United Kingdom        144
# dtype: int64
#
# Date range per country (train):
#                           min        max
# country
# Algeria            2006-01-01 2017-12-01
# Denmark            2006-01-01 2017-12-01
# Germany            2006-01-01 2017-12-01
# Italy              2006-01-01 2017-12-01
# Netherlands        2006-01-01 2017-12-01
# Norway             2006-01-01 2017-12-01
# Romania            2006-01-01 2017-12-01
# Russian Federation 2006-01-01 2017-12-01
# Turkey             2006-01-01 2017-12-01
# United Kingdom     2006-01-01 2017-12-01

# %%
# Recipe with ANOVA filter (keep top 50% of features)
rec_anova = (
    recipe()
    .step_filter_anova(outcome="refinery_kbd", top_p=0.5, use_pvalue=True)
    .step_normalize(all_numeric_predictors())
)

# Workflow
wf_anova = (
    workflow()
    .add_recipe(rec_anova)
    .add_model(linear_reg().set_engine("sklearn"))
)

# Fit and evaluate
fit_anova = wf_anova.fit_nested(train_data, group_col='country', per_group_prep=True)
fit_anova = fit_anova.evaluate(test_data)

print("✓ ANOVA filter model fitted successfully!")

fit = fit_anova

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# ✓ ANOVA filter model fitted successfully!
#            date         country   actuals    fitted  forecast  residuals  \
# 0    2006-01-01         Algeria -0.411900  0.386925 -0.411900  -0.798825
# 1    2006-02-01         Algeria -0.554261  0.593082 -0.554261  -1.147343
# 2    2006-03-01         Algeria -0.625441 -0.290919 -0.625441  -0.334522
# 3    2006-04-01         Algeria -0.401731 -0.879905 -0.401731   0.478174
# 4    2006-05-01         Algeria -1.235559 -0.676132 -1.235559  -0.559427
# ...         ...             ...       ...       ...       ...        ...
# 1915 2021-08-01  United Kingdom -1.596937 -0.773184 -1.596937  -0.823754
# 1916 2021-09-01  United Kingdom -2.022208 -0.889848 -2.022208  -1.132360
# 1917 2021-10-01  United Kingdom -2.193722 -0.933038 -2.193722  -1.260684
# 1918 2021-11-01  United Kingdom -1.539314 -1.258085 -1.539314  -0.281229
# 1919 2021-12-01  United Kingdom -1.574743 -1.093847 -1.574743  -0.480896
#
#       split       model model_group_name   group
# 0     train  linear_reg                   global
# 1     train  linear_reg                   global
# 2     train  linear_reg                   global
# 3     train  linear_reg                   global
# 4     train  linear_reg                   global
# ...     ...         ...              ...     ...
# 1915   test  linear_reg                   global
# 1916   test  linear_reg                   global
# 1917   test  linear_reg                   global
# 1918   test  linear_reg                   global
# 1919   test  linear_reg                   global
#
# [1920 rows x 10 columns]
#            country                         variable   coefficient  std_error  \
# 0          Algeria                        Intercept -8.204063e-16   0.072123
# 1          Algeria         brent_cracking_nw_europe -9.274737e-01   0.318759
# 2          Algeria               bakken_coking_usmc  2.252068e+00   0.949397
# 3          Algeria               urals_cracking_med -9.029606e-01   0.363785
# 4          Algeria  x30_70_wcs_bakken_cracking_usmc -2.540120e+00   0.945974
# ..             ...                              ...           ...        ...
# 85  United Kingdom    tapis_hydroskimming_singapore  3.771002e-02   0.212340
# 86  United Kingdom         urals_cracking_nw_europe -3.517293e-01   0.233026
# 87  United Kingdom                            brent -1.084727e+00   1.036170
# 88  United Kingdom                            dubai  8.343433e-01   1.090210
# 89  United Kingdom       es_sider_hydroskimming_med  8.107110e-02   0.132859
#
#           t_stat   p_value         vif       model model_group_name   group  \
# 0  -1.137513e-14  1.000000         NaN  linear_reg                   global
# 1  -2.909642e+00  0.004233   19.533464  linear_reg                   global
# 2   2.372104e+00  0.019099  173.280945  linear_reg                   global
# 3  -2.482129e+00  0.014287   25.441582  linear_reg                   global
# 4  -2.685190e+00  0.008158  172.033662  linear_reg                   global
# ..           ...       ...         ...         ...              ...     ...
# 85  1.775929e-01  0.859309   14.341151  linear_reg                   global
# 86 -1.509399e+00  0.133534   17.271511  linear_reg                   global
# 87 -1.046862e+00  0.297034  341.494573  linear_reg                   global
# 88  7.653051e-01  0.445426  378.043628  linear_reg                   global
# 89  6.102020e-01  0.542754    5.614439  linear_reg                   global
#
#     ci_0.025  ci_0.975
# 0  -0.142637  0.142637
# 1  -1.557880 -0.297067
# 2   0.374453  4.129683
# 3  -1.622415 -0.183506
# 4  -4.410965 -0.669275
# ..       ...       ...
# 85 -0.382233  0.457653
# 86 -0.812583  0.109124
# 87 -3.133953  0.964499
# 88 -1.321757  2.990443
# 89 -0.181684  0.343826
#
# [90 rows x 12 columns]
#             country  split            metric                          value  \
# 0           Algeria  train              rmse                       0.837991
# 1           Algeria  train               mae                       0.614109
# 2           Algeria  train              mape                     369.554022
# 3           Algeria  train             smape                     119.164737
# 4           Algeria  train         r_squared                       0.297771
# ..              ...    ...               ...                            ...
# 255  United Kingdom               model_type                     linear_reg
# 256  United Kingdom              model_class               LinearRegression
# 257  United Kingdom  train       n_obs_train                            144
# 258  United Kingdom  train  train_start_date  2006-01-01T00:00:00.000000000
# 259  United Kingdom  train    train_end_date  2017-12-01T00:00:00.000000000
#
#           model model_group_name   group
# 0    linear_reg                   global
# 1    linear_reg                   global
# 2    linear_reg                   global
# 3    linear_reg                   global
# 4    linear_reg                   global
# ..          ...              ...     ...
# 255  linear_reg                   global
# 256  linear_reg                   global
# 257  linear_reg                   global
# 258  linear_reg                   global
# 259  linear_reg                   global
#
# [260 rows x 7 columns]
#            date         country  brent_cracking_nw_europe  bakken_coking_usmc  \
# 1430 2017-03-01  United Kingdom                       NaN                 NaN
# 1431 2017-04-01  United Kingdom                       NaN                 NaN
# 1432 2017-05-01  United Kingdom                       NaN                 NaN
# 1433 2017-06-01  United Kingdom                       NaN                 NaN
# 1434 2017-07-01  United Kingdom                       NaN                 NaN
# 1435 2017-08-01  United Kingdom                       NaN                 NaN
# 1436 2017-09-01  United Kingdom                       NaN                 NaN
# 1437 2017-10-01  United Kingdom                       NaN                 NaN
# 1438 2017-11-01  United Kingdom                       NaN                 NaN
# 1439 2017-12-01  United Kingdom                       NaN                 NaN
#
#       urals_cracking_med  x30_70_wcs_bakken_cracking_usmc  \
# 1430           -0.131079                              NaN
# 1431            0.158431                              NaN
# 1432            0.058354                              NaN
# 1433            0.133412                              NaN
# 1434            0.340715                              NaN
# 1435            0.433644                              NaN
# 1436            0.912586                              NaN
# 1437            0.144134                              NaN
# 1438           -0.356253                              NaN
# 1439           -0.677930                              NaN
#
#       urals_cracking_nw_europe  es_sider_cracking_med     brent     dubai  \
# 1430                 -0.052598                    NaN -1.057443 -1.014581
# 1431                  0.507125                    NaN -1.019196 -0.964241
# 1432                  0.094280                    NaN -1.099098 -1.047751
# 1433                  0.356277                    NaN -1.249813 -1.198771
# 1434                  0.407883                    NaN -1.181650 -1.152333
# 1435                  0.661942                    NaN -1.080163 -1.043068
# 1436                  1.277240                    NaN -0.936643 -0.909219
# 1437                  0.388035                    NaN -0.843487 -0.842099
# 1438                 -0.008932                    NaN -0.656040 -0.646983
# 1439                 -0.933864                    NaN -0.593936 -0.614594
#
#       ...  urals_hydroskimming_nw_europe  urals_hydroskimming_med  \
# 1430  ...                            NaN                      NaN
# 1431  ...                            NaN                      NaN
# 1432  ...                            NaN                      NaN
# 1433  ...                            NaN                      NaN
# 1434  ...                            NaN                      NaN
# 1435  ...                            NaN                      NaN
# 1436  ...                            NaN                      NaN
# 1437  ...                            NaN                      NaN
# 1438  ...                            NaN                      NaN
# 1439  ...                            NaN                      NaN
#
#       brent_hydroskimming_nw_europe  x50_50_hls_lls_cracking_usgc  \
# 1430                            NaN                      1.097357
# 1431                            NaN                      1.457779
# 1432                            NaN                      1.231228
# 1433                            NaN                      1.498971
# 1434                            NaN                      1.423454
# 1435                            NaN                      1.420021
# 1436                            NaN                      1.166009
# 1437                            NaN                      0.953188
# 1438                            NaN                      0.754098
# 1439                            NaN                      0.551575
#
#       dubai_cracking_singapore  es_sider_hydroskimming_med  \
# 1430                       NaN                    0.767560
# 1431                       NaN                    1.454312
# 1432                       NaN                    1.286916
# 1433                       NaN                    1.797689
# 1434                       NaN                    1.621708
# 1435                       NaN                    1.492942
# 1436                       NaN                    1.359884
# 1437                       NaN                    0.844819
# 1438                       NaN                    0.613040
# 1439                       NaN                   -0.005037
#
#       tapis_hydroskimming_singapore       wti  dubai_hydroskimming_singapore  \
# 1430                       0.793128 -1.112604                            NaN
# 1431                       1.134777 -1.048256                            NaN
# 1432                       0.783177 -1.159561                            NaN
# 1433                       0.886004 -1.304345                            NaN
# 1434                       0.952343 -1.239997                            NaN
# 1435                       1.204434 -1.179996                            NaN
# 1436                       1.035268 -1.101735                            NaN
# 1437                       0.829615 -1.026517                            NaN
# 1438                       0.643864 -0.805211                            NaN
# 1439                       0.534403 -0.749124                            NaN
#
#       split
# 1430  train
# 1431  train
# 1432  train
# 1433  train
# 1434  train
# 1435  train
# 1436  train
# 1437  train
# 1438  train
# 1439  train
#
# [10 rows x 21 columns]
#         date  country  brent_cracking_nw_europe  bakken_coking_usmc  \
# 0 2018-01-01  Algeria                 -0.615285           -0.171070
# 1 2018-02-01  Algeria                 -0.290507           -0.628337
# 2 2018-03-01  Algeria                 -0.948498           -0.458053
# 3 2018-04-01  Algeria                 -0.286289            0.008741
# 4 2018-05-01  Algeria                 -0.117574            0.599378
# 5 2018-06-01  Algeria                  0.046924            0.435047
# 6 2018-07-01  Algeria                  0.055360            0.140920
# 7 2018-08-01  Algeria                  1.033910            0.439811
# 8 2018-09-01  Algeria                 -0.429698            0.458863
# 9 2018-10-01  Algeria                 -1.281711           -0.025792
#
#    urals_cracking_med  x30_70_wcs_bakken_cracking_usmc  \
# 0           -0.774433                        -0.184520
# 1           -0.009556                        -0.622057
# 2           -0.002408                        -0.448739
# 3            0.119115                        -0.002719
# 4           -0.052446                         0.571775
# 5           -0.220433                         0.436030
# 6            0.097670                         0.188779
# 7            0.744599                         0.460270
# 8           -0.660059                         0.443302
# 9           -0.502795                         0.021522
#
#    urals_cracking_nw_europe  es_sider_cracking_med     brent     dubai  ...  \
# 0                 -1.001348              -0.532182 -0.412926 -0.434697  ...
# 1                 -0.239172              -0.364974 -0.548116 -0.560742  ...
# 2                 -0.540867              -0.238549 -0.509111 -0.541230  ...
# 3                  0.086340               0.140727 -0.312954 -0.340651  ...
# 4                 -0.004962               0.189666 -0.122856 -0.136559  ...
# 5                  0.094280               0.471065 -0.178143 -0.153730  ...
# 6                  0.300702               0.532238 -0.206545 -0.173241  ...
# 7                  0.753244               1.429450 -0.256152 -0.196265  ...
# 8                 -0.552776              -0.116201 -0.039167 -0.005442  ...
# 9                 -0.588503              -0.511790  0.021800  0.070263  ...
#
#    urals_hydroskimming_nw_europe  urals_hydroskimming_med  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
# 5                            NaN                      NaN
# 6                            NaN                      NaN
# 7                            NaN                      NaN
# 8                            NaN                      NaN
# 9                            NaN                      NaN
#
#    brent_hydroskimming_nw_europe  x50_50_hls_lls_cracking_usgc  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# 5                            NaN                           NaN
# 6                            NaN                           NaN
# 7                            NaN                           NaN
# 8                            NaN                           NaN
# 9                            NaN                           NaN
#
#    dubai_cracking_singapore  es_sider_hydroskimming_med  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# 5                       NaN                         NaN
# 6                       NaN                         NaN
# 7                       NaN                         NaN
# 8                       NaN                         NaN
# 9                       NaN                         NaN
#
#    tapis_hydroskimming_singapore  wti  dubai_hydroskimming_singapore  split
# 0                            NaN  NaN                            NaN   test
# 1                            NaN  NaN                            NaN   test
# 2                            NaN  NaN                            NaN   test
# 3                            NaN  NaN                            NaN   test
# 4                            NaN  NaN                            NaN   test
# 5                            NaN  NaN                            NaN   test
# 6                            NaN  NaN                            NaN   test
# 7                            NaN  NaN                            NaN   test
# 8                            NaN  NaN                            NaN   test
# 9                            NaN  NaN                            NaN   test
#
# [10 rows x 21 columns]
#                     bakken_coking_usmc  brent  brent_cracking_nw_europe  \
# Algeria                           True   True                      True
# Denmark                           True  False                      True
# Germany                           True  False                      True
# Italy                             True  False                      True
# Netherlands                      False   True                     False
# Norway                            True  False                     False
# Romania                           True   True                      True
# Russian Federation                True  False                     False
# Turkey                           False   True                      True
# United Kingdom                   False   True                     False
#
#                     brent_hydroskimming_nw_europe  dubai  \
# Algeria                                     False   True
# Denmark                                      True  False
# Germany                                     False  False
# Italy                                       False  False
# Netherlands                                 False   True
# Norway                                       True  False
# Romania                                     False   True
# Russian Federation                          False  False
# Turkey                                      False   True
# United Kingdom                              False   True
#
#                     dubai_cracking_singapore  dubai_hydroskimming_singapore  \
# Algeria                                False                          False
# Denmark                                False                          False
# Germany                                 True                          False
# Italy                                  False                          False
# Netherlands                            False                          False
# Norway                                  True                          False
# Romania                                False                          False
# Russian Federation                     False                           True
# Turkey                                 False                          False
# United Kingdom                         False                          False
#
#                     es_sider_cracking_med  es_sider_hydroskimming_med  \
# Algeria                              True                       False
# Denmark                             False                       False
# Germany                              True                       False
# Italy                               False                        True
# Netherlands                         False                        True
# Norway                              False                        True
# Romania                             False                       False
# Russian Federation                  False                        True
# Turkey                               True                       False
# United Kingdom                      False                        True
#
#                     tapis_hydroskimming_singapore  urals_cracking_med  \
# Algeria                                     False                True
# Denmark                                     False                True
# Germany                                     False                True
# Italy                                       False                True
# Netherlands                                  True               False
# Norway                                      False                True
# Romania                                     False                True
# Russian Federation                           True                True
# Turkey                                       True                True
# United Kingdom                               True                True
#
#                     urals_cracking_nw_europe  urals_hydroskimming_med  \
# Algeria                                 True                    False
# Denmark                                 True                     True
# Germany                                 True                    False
# Italy                                   True                     True
# Netherlands                            False                     True
# Norway                                 False                     True
# Romania                                 True                     True
# Russian Federation                      True                    False
# Turkey                                  True                     True
# United Kingdom                          True                    False
#
#                     urals_hydroskimming_nw_europe    wti  \
# Algeria                                     False  False
# Denmark                                      True  False
# Germany                                     False  False
# Italy                                       False  False
# Netherlands                                  True   True
# Norway                                       True  False
# Romania                                     False  False
# Russian Federation                          False  False
# Turkey                                      False  False
# United Kingdom                              False   True
#
#                     x30_70_wcs_bakken_cracking_usmc  \
# Algeria                                        True
# Denmark                                        True
# Germany                                        True
# Italy                                          True
# Netherlands                                   False
# Norway                                        False
# Romania                                        True
# Russian Federation                             True
# Turkey                                        False
# United Kingdom                                False
#
#                     x50_50_hls_lls_cracking_usgc
# Algeria                                    False
# Denmark                                    False
# Germany                                     True
# Italy                                       True
# Netherlands                                 True
# Norway                                      True
# Romania                                    False
# Russian Federation                          True
# Turkey                                     False
# United Kingdom                              True

# %%
# Recipe with RF importance filter (keep top 5 features)
rec_rf_imp = (
    recipe()
    .step_filter_rf_importance(outcome="refinery_kbd", top_n=5, trees=50)
    .step_normalize(all_numeric_predictors())
)

# Workflow
wf_rf_imp = (
    workflow()
    .add_recipe(rec_rf_imp)
    .add_model(linear_reg().set_engine("sklearn"))
)

# Fit and evaluate
fit_rf_imp = wf_rf_imp.fit_nested(train_data, group_col='country', per_group_prep=True)
fit_rf_imp = fit_rf_imp.evaluate(test_data)

print("✓ RF importance filter model fitted successfully!")

fit = fit_rf_imp

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# ✓ RF importance filter model fitted successfully!
#            date         country   actuals    fitted  forecast  residuals  \
# 0    2006-01-01         Algeria -0.411900  0.256843 -0.411900  -0.668743
# 1    2006-02-01         Algeria -0.554261  0.281241 -0.554261  -0.835502
# 2    2006-03-01         Algeria -0.625441  0.024619 -0.625441  -0.650060
# 3    2006-04-01         Algeria -0.401731 -0.128815 -0.401731  -0.272917
# 4    2006-05-01         Algeria -1.235559 -0.222503 -1.235559  -1.013056
# ...         ...             ...       ...       ...       ...        ...
# 1915 2021-08-01  United Kingdom -1.596937 -0.759252 -1.596937  -0.837685
# 1916 2021-09-01  United Kingdom -2.022208 -0.834744 -2.022208  -1.187465
# 1917 2021-10-01  United Kingdom -2.193722 -0.819476 -2.193722  -1.374246
# 1918 2021-11-01  United Kingdom -1.539314 -1.127984 -1.539314  -0.411330
# 1919 2021-12-01  United Kingdom -1.574743 -1.111791 -1.574743  -0.462952
#
#       split       model model_group_name   group
# 0     train  linear_reg                   global
# 1     train  linear_reg                   global
# 2     train  linear_reg                   global
# 3     train  linear_reg                   global
# 4     train  linear_reg                   global
# ...     ...         ...              ...     ...
# 1915   test  linear_reg                   global
# 1916   test  linear_reg                   global
# 1917   test  linear_reg                   global
# 1918   test  linear_reg                   global
# 1919   test  linear_reg                   global
#
# [1920 rows x 10 columns]
#                country                         variable   coefficient  \
# 0              Algeria                        Intercept -1.580487e-15
# 1              Algeria                            dubai  1.590272e+00
# 2              Algeria                            brent -1.773128e+00
# 3              Algeria               bakken_coking_usmc -4.266878e-01
# 4              Algeria       es_sider_hydroskimming_med -1.323033e-01
# 5              Algeria  x30_70_wcs_bakken_cracking_usmc  2.591804e-01
# 6              Denmark                        Intercept -1.024697e-15
# 7              Denmark                            dubai  1.414148e+00
# 8              Denmark                            brent -1.443599e+00
# 9              Denmark         dubai_cracking_singapore  3.095503e-02
# 10             Denmark  x30_70_wcs_bakken_cracking_usmc -4.788785e-01
# 11             Denmark               bakken_coking_usmc  2.959789e-01
# 12             Germany                        Intercept  3.046215e-15
# 13             Germany               urals_cracking_med  5.309361e-01
# 14             Germany                            dubai -4.139629e+00
# 15             Germany                            brent  4.123087e+00
# 16             Germany         urals_cracking_nw_europe -7.943977e-02
# 17             Germany               bakken_coking_usmc -3.337158e-01
# 18               Italy                        Intercept -6.601006e-17
# 19               Italy     x50_50_hls_lls_cracking_usgc -6.881605e-01
# 20               Italy               urals_cracking_med  6.451169e-01
# 21               Italy                            dubai -6.883038e-02
# 22               Italy                            brent -1.797465e-01
# 23               Italy  x30_70_wcs_bakken_cracking_usmc -1.491921e-01
# 24         Netherlands                        Intercept  2.940537e-15
# 25         Netherlands                            brent  2.076953e+00
# 26         Netherlands                            dubai -1.793090e+00
# 27         Netherlands    tapis_hydroskimming_singapore  4.446253e-01
# 28         Netherlands               urals_cracking_med -5.229907e-01
# 29         Netherlands          urals_hydroskimming_med  5.576216e-01
# 30              Norway                        Intercept -2.408915e-15
# 31              Norway                            brent -2.239301e+00
# 32              Norway                            dubai  2.192601e+00
# 33              Norway         brent_cracking_nw_europe  1.752887e-01
# 34              Norway    brent_hydroskimming_nw_europe -4.085012e-01
# 35              Norway         dubai_cracking_singapore  2.331386e-01
# 36             Romania                        Intercept  2.399412e-15
# 37             Romania                            brent  3.173866e+00
# 38             Romania                            dubai -3.263359e+00
# 39             Romania               urals_cracking_med  2.926748e-01
# 40             Romania         urals_cracking_nw_europe  7.039003e-02
# 41             Romania  x30_70_wcs_bakken_cracking_usmc -3.799101e-01
# 42  Russian Federation                        Intercept -2.096945e-16
# 43  Russian Federation     x50_50_hls_lls_cracking_usgc  8.189229e-01
# 44  Russian Federation                            dubai -8.422977e-01
# 45  Russian Federation               urals_cracking_med -6.664237e-01
# 46  Russian Federation                            brent  1.102651e+00
# 47  Russian Federation  x30_70_wcs_bakken_cracking_usmc  1.207221e-01
# 48              Turkey                        Intercept  3.428419e-15
# 49              Turkey                            brent  3.963658e+00
# 50              Turkey                            dubai -4.339305e+00
# 51              Turkey         urals_cracking_nw_europe  1.766161e-01
# 52              Turkey            es_sider_cracking_med  3.630852e-01
# 53              Turkey               urals_cracking_med -1.140695e-01
# 54      United Kingdom                        Intercept -1.014965e-15
# 55      United Kingdom                            brent -1.026801e+00
# 56      United Kingdom     x50_50_hls_lls_cracking_usgc -7.015407e-01
# 57      United Kingdom                              wti  2.102820e-01
# 58      United Kingdom                            dubai  8.104605e-01
# 59      United Kingdom               urals_cracking_med  6.204271e-01
#
#     std_error        t_stat       p_value         vif       model  \
# 0    0.080420 -1.965297e-14  1.000000e+00         NaN  linear_reg
# 1    1.519709  1.046432e+00  2.971911e-01  357.105088  linear_reg
# 2    1.540318 -1.151144e+00  2.516636e-01  366.856012  linear_reg
# 3    0.811128 -5.260423e-01  5.997032e-01  101.731220  linear_reg
# 4    0.108507 -1.219302e+00  2.248097e-01    1.820513  linear_reg
# 5    0.807593  3.209295e-01  7.487493e-01  100.846292  linear_reg
# 6    0.083254 -1.230814e-14  1.000000e+00         NaN  linear_reg
# 7    1.615417  8.754078e-01  3.828732e-01  376.498378  linear_reg
# 8    1.606983 -8.983287e-01  3.705750e-01  372.577591  linear_reg
# 9    0.115034  2.690947e-01  7.882587e-01    1.909177  linear_reg
# 10   0.866481 -5.526706e-01  5.813831e-01  108.320824  linear_reg
# 11   0.877606  3.372573e-01  7.364354e-01  111.120176  linear_reg
# 12   0.065630  4.641502e-14  1.000000e+00         NaN  linear_reg
# 13   0.260354  2.039285e+00  4.333021e-02   15.737097  linear_reg
# 14   1.082034 -3.825786e+00  1.967983e-04  271.817606  linear_reg
# 15   1.104001  3.734676e+00  2.741203e-04  282.966694  linear_reg
# 16   0.270223 -2.939789e-01  7.692157e-01   16.952737  linear_reg
# 17   0.081775 -4.080926e+00  7.553459e-05    1.552502  linear_reg
# 18   0.055631 -1.186562e-15  1.000000e+00         NaN  linear_reg
# 19   0.074543 -9.231784e+00  4.440892e-16    1.795431  linear_reg
# 20   0.064095  1.006508e+01  0.000000e+00    1.327402  linear_reg
# 21   0.919266 -7.487537e-02  9.404223e-01  273.050434  linear_reg
# 22   0.932928 -1.926692e-01  8.475013e-01  281.227022  linear_reg
# 23   0.064497 -2.313175e+00  2.219127e-02    1.344112  linear_reg
# 24   0.075546  3.892394e-14  1.000000e+00         NaN  linear_reg
# 25   1.391469  1.492634e+00  1.378157e-01  339.255762  linear_reg
# 26   1.339409 -1.338717e+00  1.828640e-01  314.345419  linear_reg
# 27   0.114025  3.899354e+00  1.499803e-04    2.278157  linear_reg
# 28   0.143801 -3.636913e+00  3.887085e-04    3.623284  linear_reg
# 29   0.152098  3.666188e+00  3.503505e-04    4.053498  linear_reg
# 30   0.081698 -2.948547e-14  1.000000e+00         NaN  linear_reg
# 31   1.922168 -1.164987e+00  2.460340e-01  553.548737  linear_reg
# 32   1.900114  1.153932e+00  2.505227e-01  540.919090  linear_reg
# 33   0.158076  1.108892e+00  2.694055e-01    3.743714  linear_reg
# 34   0.159738 -2.557312e+00  1.162887e-02    3.822895  linear_reg
# 35   0.134490  1.733500e+00  8.524036e-02    2.709904  linear_reg
# 36   0.067751  3.541511e-14  1.000000e+00         NaN  linear_reg
# 37   1.126698  2.816962e+00  5.559730e-03  276.555874  linear_reg
# 38   1.106341 -2.949686e+00  3.737753e-03  266.652556  linear_reg
# 39   0.270434  1.082242e+00  2.810324e-01   15.932699  linear_reg
# 40   0.278072  2.531358e-01  8.005400e-01   16.845454  linear_reg
# 41   0.083536 -4.547858e+00  1.174983e-05    1.520251  linear_reg
# 42   0.050181 -4.178775e-15  1.000000e+00         NaN  linear_reg
# 43   0.067239  1.217925e+01  0.000000e+00    1.795431  linear_reg
# 44   0.829200 -1.015795e+00  3.115047e-01  273.050434  linear_reg
# 45   0.057815 -1.152686e+01  0.000000e+00    1.327402  linear_reg
# 46   0.841524  1.310302e+00  1.922704e-01  281.227022  linear_reg
# 47   0.058178  2.075062e+00  3.983789e-02    1.344112  linear_reg
# 48   0.062818  5.457728e-14  1.000000e+00         NaN  linear_reg
# 49   1.065715  3.719247e+00  2.897800e-04  287.818196  linear_reg
# 50   1.059626 -4.095127e+00  7.152393e-05  284.538876  linear_reg
# 51   0.243154  7.263538e-01  4.688521e-01   14.983048  linear_reg
# 52   0.143206  2.535410e+00  1.234636e-02    5.197048  linear_reg
# 53   0.229888 -4.961952e-01  6.205461e-01   13.392752  linear_reg
# 54   0.055975 -1.813234e-14  1.000000e+00         NaN  linear_reg
# 55   0.923068 -1.112379e+00  2.679093e-01  271.939734  linear_reg
# 56   0.077277 -9.078291e+00  8.881784e-16    1.905914  linear_reg
# 57   0.260737  8.064908e-01  4.213476e-01   21.697572  linear_reg
# 58   0.939965  8.622243e-01  3.900600e-01  281.986895  linear_reg
# 59   0.072115  8.603263e+00  1.532108e-14    1.659820  linear_reg
#
#    model_group_name   group  ci_0.025  ci_0.975
# 0                    global -0.159014  0.159014
# 1                    global -1.414654  4.595199
# 2                    global -4.818803  1.272548
# 3                    global -2.030535  1.177159
# 4                    global -0.346855  0.082249
# 5                    global -1.337676  1.856037
# 6                    global -0.164618  0.164618
# 7                    global -1.780021  4.608317
# 8                    global -4.621093  1.733894
# 9                    global -0.196502  0.258412
# 10                   global -2.192174  1.234417
# 11                   global -1.439314  2.031272
# 12                   global -0.129770  0.129770
# 13                   global  0.016137  1.045735
# 14                   global -6.279137 -2.000120
# 15                   global  1.940141  6.306032
# 16                   global -0.613752  0.454873
# 17                   global -0.495409 -0.172023
# 18                   global -0.110000  0.110000
# 19                   global -0.835554 -0.540767
# 20                   global  0.518383  0.771851
# 21                   global -1.886498  1.748837
# 22                   global -2.024429  1.664936
# 23                   global -0.276722 -0.021663
# 24                   global -0.149377  0.149377
# 25                   global -0.674402  4.828309
# 26                   global -4.441510  0.855329
# 27                   global  0.219163  0.670088
# 28                   global -0.807328 -0.238653
# 29                   global  0.256877  0.858366
# 30                   global -0.161542  0.161542
# 31                   global -6.040011  1.561408
# 32                   global -1.564500  5.949703
# 33                   global -0.137275  0.487852
# 34                   global -0.724353 -0.092650
# 35                   global -0.032789  0.499066
# 36                   global -0.133964  0.133964
# 37                   global  0.946041  5.401690
# 38                   global -5.450931 -1.075787
# 39                   global -0.242055  0.827404
# 40                   global -0.479443  0.620223
# 41                   global -0.545086 -0.214734
# 42                   global -0.099223  0.099223
# 43                   global  0.685971  0.951875
# 44                   global -2.481879  0.797283
# 45                   global -0.780741 -0.552106
# 46                   global -0.561298  2.766600
# 47                   global  0.005687  0.235757
# 48                   global -0.124210  0.124210
# 49                   global  1.856416  6.070900
# 50                   global -6.434508 -2.244102
# 51                   global -0.304174  0.657406
# 52                   global  0.079924  0.646246
# 53                   global -0.568628  0.340489
# 54                   global -0.110680  0.110680
# 55                   global -2.851985  0.798384
# 56                   global -0.854340 -0.548741
# 57                   global -0.305274  0.725838
# 58                   global -1.048135  2.669056
# 59                   global  0.477833  0.763021
#             country  split            metric                          value  \
# 0           Algeria  train              rmse                       0.944718
# 1           Algeria  train               mae                       0.723473
# 2           Algeria  train              mape                     347.196021
# 3           Algeria  train             smape                        148.871
# 4           Algeria  train         r_squared                       0.107508
# ..              ...    ...               ...                            ...
# 255  United Kingdom               model_type                     linear_reg
# 256  United Kingdom              model_class               LinearRegression
# 257  United Kingdom  train       n_obs_train                            144
# 258  United Kingdom  train  train_start_date  2006-01-01T00:00:00.000000000
# 259  United Kingdom  train    train_end_date  2017-12-01T00:00:00.000000000
#
#           model model_group_name   group
# 0    linear_reg                   global
# 1    linear_reg                   global
# 2    linear_reg                   global
# 3    linear_reg                   global
# 4    linear_reg                   global
# ..          ...              ...     ...
# 255  linear_reg                   global
# 256  linear_reg                   global
# 257  linear_reg                   global
# 258  linear_reg                   global
# 259  linear_reg                   global
#
# [260 rows x 7 columns]
#            date         country     dubai     brent  bakken_coking_usmc  \
# 1430 2017-03-01  United Kingdom -1.014581 -1.057443                 NaN
# 1431 2017-04-01  United Kingdom -0.964241 -1.019196                 NaN
# 1432 2017-05-01  United Kingdom -1.047751 -1.099098                 NaN
# 1433 2017-06-01  United Kingdom -1.198771 -1.249813                 NaN
# 1434 2017-07-01  United Kingdom -1.152333 -1.181650                 NaN
# 1435 2017-08-01  United Kingdom -1.043068 -1.080163                 NaN
# 1436 2017-09-01  United Kingdom -0.909219 -0.936643                 NaN
# 1437 2017-10-01  United Kingdom -0.842099 -0.843487                 NaN
# 1438 2017-11-01  United Kingdom -0.646983 -0.656040                 NaN
# 1439 2017-12-01  United Kingdom -0.614594 -0.593936                 NaN
#
#       es_sider_hydroskimming_med  x30_70_wcs_bakken_cracking_usmc  \
# 1430                         NaN                              NaN
# 1431                         NaN                              NaN
# 1432                         NaN                              NaN
# 1433                         NaN                              NaN
# 1434                         NaN                              NaN
# 1435                         NaN                              NaN
# 1436                         NaN                              NaN
# 1437                         NaN                              NaN
# 1438                         NaN                              NaN
# 1439                         NaN                              NaN
#
#       refinery_kbd  dubai_cracking_singapore  urals_cracking_med  \
# 1430     -1.261554                       NaN           -0.131079
# 1431     -1.144334                       NaN            0.158431
# 1432     -1.325671                       NaN            0.058354
# 1433     -1.069161                       NaN            0.133412
# 1434     -1.268952                       NaN            0.340715
# 1435     -0.969327                       NaN            0.433644
# 1436     -0.972327                       NaN            0.912586
# 1437     -1.138251                       NaN            0.144134
# 1438     -1.420820                       NaN           -0.356253
# 1439     -1.329370                       NaN           -0.677930
#
#       urals_cracking_nw_europe  x50_50_hls_lls_cracking_usgc  \
# 1430                       NaN                      1.097357
# 1431                       NaN                      1.457779
# 1432                       NaN                      1.231228
# 1433                       NaN                      1.498971
# 1434                       NaN                      1.423454
# 1435                       NaN                      1.420021
# 1436                       NaN                      1.166009
# 1437                       NaN                      0.953188
# 1438                       NaN                      0.754098
# 1439                       NaN                      0.551575
#
#       tapis_hydroskimming_singapore  urals_hydroskimming_med  \
# 1430                            NaN                      NaN
# 1431                            NaN                      NaN
# 1432                            NaN                      NaN
# 1433                            NaN                      NaN
# 1434                            NaN                      NaN
# 1435                            NaN                      NaN
# 1436                            NaN                      NaN
# 1437                            NaN                      NaN
# 1438                            NaN                      NaN
# 1439                            NaN                      NaN
#
#       brent_cracking_nw_europe  brent_hydroskimming_nw_europe  \
# 1430                       NaN                            NaN
# 1431                       NaN                            NaN
# 1432                       NaN                            NaN
# 1433                       NaN                            NaN
# 1434                       NaN                            NaN
# 1435                       NaN                            NaN
# 1436                       NaN                            NaN
# 1437                       NaN                            NaN
# 1438                       NaN                            NaN
# 1439                       NaN                            NaN
#
#       es_sider_cracking_med       wti  split
# 1430                    NaN -1.112604  train
# 1431                    NaN -1.048256  train
# 1432                    NaN -1.159561  train
# 1433                    NaN -1.304345  train
# 1434                    NaN -1.239997  train
# 1435                    NaN -1.179996  train
# 1436                    NaN -1.101735  train
# 1437                    NaN -1.026517  train
# 1438                    NaN -0.805211  train
# 1439                    NaN -0.749124  train
#         date  country     dubai     brent  bakken_coking_usmc  \
# 0 2018-01-01  Algeria -0.434697 -0.412926           -0.171070
# 1 2018-02-01  Algeria -0.560742 -0.548116           -0.628337
# 2 2018-03-01  Algeria -0.541230 -0.509111           -0.458053
# 3 2018-04-01  Algeria -0.340651 -0.312954            0.008741
# 4 2018-05-01  Algeria -0.136559 -0.122856            0.599378
# 5 2018-06-01  Algeria -0.153730 -0.178143            0.435047
# 6 2018-07-01  Algeria -0.173241 -0.206545            0.140920
# 7 2018-08-01  Algeria -0.196265 -0.256152            0.439811
# 8 2018-09-01  Algeria -0.005442 -0.039167            0.458863
# 9 2018-10-01  Algeria  0.070263  0.021800           -0.025792
#
#    es_sider_hydroskimming_med  x30_70_wcs_bakken_cracking_usmc  refinery_kbd  \
# 0                   -0.292615                        -0.184520      0.798167
# 1                   -0.056544                        -0.622057      1.123563
# 2                    0.029300                        -0.448739      1.235418
# 3                    0.115144                        -0.002719      1.520140
# 4                    0.308294                         0.571775      0.289735
# 5                    0.939248                         0.436030      0.198218
# 6                    1.063722                         0.188779     -0.615273
# 7                    1.801981                         0.460270      1.418453
# 8                    0.076515                         0.443302      1.784524
# 9                   -0.017914                         0.021522      1.225249
#
#    dubai_cracking_singapore  urals_cracking_med  urals_cracking_nw_europe  \
# 0                       NaN                 NaN                       NaN
# 1                       NaN                 NaN                       NaN
# 2                       NaN                 NaN                       NaN
# 3                       NaN                 NaN                       NaN
# 4                       NaN                 NaN                       NaN
# 5                       NaN                 NaN                       NaN
# 6                       NaN                 NaN                       NaN
# 7                       NaN                 NaN                       NaN
# 8                       NaN                 NaN                       NaN
# 9                       NaN                 NaN                       NaN
#
#    x50_50_hls_lls_cracking_usgc  tapis_hydroskimming_singapore  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
# 5                           NaN                            NaN
# 6                           NaN                            NaN
# 7                           NaN                            NaN
# 8                           NaN                            NaN
# 9                           NaN                            NaN
#
#    urals_hydroskimming_med  brent_cracking_nw_europe  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
# 5                      NaN                       NaN
# 6                      NaN                       NaN
# 7                      NaN                       NaN
# 8                      NaN                       NaN
# 9                      NaN                       NaN
#
#    brent_hydroskimming_nw_europe  es_sider_cracking_med  wti split
# 0                            NaN                    NaN  NaN  test
# 1                            NaN                    NaN  NaN  test
# 2                            NaN                    NaN  NaN  test
# 3                            NaN                    NaN  NaN  test
# 4                            NaN                    NaN  NaN  test
# 5                            NaN                    NaN  NaN  test
# 6                            NaN                    NaN  NaN  test
# 7                            NaN                    NaN  NaN  test
# 8                            NaN                    NaN  NaN  test
# 9                            NaN                    NaN  NaN  test
#                     bakken_coking_usmc  brent  brent_cracking_nw_europe  \
# Algeria                           True   True                     False
# Denmark                           True   True                     False
# Germany                           True   True                     False
# Italy                            False   True                     False
# Netherlands                      False   True                     False
# Norway                           False   True                      True
# Romania                          False   True                     False
# Russian Federation               False   True                     False
# Turkey                           False   True                     False
# United Kingdom                   False   True                     False
#
#                     brent_hydroskimming_nw_europe  dubai  \
# Algeria                                     False   True
# Denmark                                     False   True
# Germany                                     False   True
# Italy                                       False   True
# Netherlands                                 False   True
# Norway                                       True   True
# Romania                                     False   True
# Russian Federation                          False   True
# Turkey                                      False   True
# United Kingdom                              False   True
#
#                     dubai_cracking_singapore  es_sider_cracking_med  \
# Algeria                                False                  False
# Denmark                                 True                  False
# Germany                                False                  False
# Italy                                  False                  False
# Netherlands                            False                  False
# Norway                                  True                  False
# Romania                                False                  False
# Russian Federation                     False                  False
# Turkey                                 False                   True
# United Kingdom                         False                  False
#
#                     es_sider_hydroskimming_med  tapis_hydroskimming_singapore  \
# Algeria                                   True                          False
# Denmark                                  False                          False
# Germany                                  False                          False
# Italy                                    False                          False
# Netherlands                              False                           True
# Norway                                   False                          False
# Romania                                  False                          False
# Russian Federation                       False                          False
# Turkey                                   False                          False
# United Kingdom                           False                          False
#
#                     urals_cracking_med  urals_cracking_nw_europe  \
# Algeria                          False                     False
# Denmark                          False                     False
# Germany                           True                      True
# Italy                             True                     False
# Netherlands                       True                     False
# Norway                           False                     False
# Romania                           True                      True
# Russian Federation                True                     False
# Turkey                            True                      True
# United Kingdom                    True                     False
#
#                     urals_hydroskimming_med    wti  \
# Algeria                               False  False
# Denmark                               False  False
# Germany                               False  False
# Italy                                 False  False
# Netherlands                            True  False
# Norway                                False  False
# Romania                               False  False
# Russian Federation                    False  False
# Turkey                                False  False
# United Kingdom                        False   True
#
#                     x30_70_wcs_bakken_cracking_usmc  \
# Algeria                                        True
# Denmark                                        True
# Germany                                       False
# Italy                                          True
# Netherlands                                   False
# Norway                                        False
# Romania                                        True
# Russian Federation                             True
# Turkey                                        False
# United Kingdom                                False
#
#                     x50_50_hls_lls_cracking_usgc
# Algeria                                    False
# Denmark                                    False
# Germany                                    False
# Italy                                       True
# Netherlands                                False
# Norway                                     False
# Romania                                    False
# Russian Federation                          True
# Turkey                                     False
# United Kingdom                              True

# %%
# Recipe with mutual information filter (keep top 6 features)
rec_mi = (
    recipe()
    .step_filter_mutual_info(outcome="refinery_kbd", top_n=6, n_neighbors=3)
    .step_normalize(all_numeric_predictors())
)

# Workflow
wf_mi = (
    workflow()
    .add_recipe(rec_mi)
    .add_model(linear_reg().set_engine("sklearn"))
)

# Fit and evaluate
fit_mi = wf_mi.fit_nested(train_data, group_col='country')
fit_mi = fit_mi.evaluate(test_data)

print("✓ Mutual information filter model fitted successfully!")

outputs_mi, coefs_mi, stats_mi = fit_mi.extract_outputs()

fit = fit_mi

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# ✓ Mutual information filter model fitted successfully!
#            date         country   actuals    fitted  forecast  residuals  \
# 0    2006-01-01         Algeria -0.411900  0.109772 -0.411900  -0.521672
# 1    2006-02-01         Algeria -0.554261  0.230906 -0.554261  -0.785166
# 2    2006-03-01         Algeria -0.625441 -0.005565 -0.625441  -0.619876
# 3    2006-04-01         Algeria -0.401731 -0.277377 -0.401731  -0.124354
# 4    2006-05-01         Algeria -1.235559 -0.064636 -1.235559  -1.170923
# ...         ...             ...       ...       ...       ...        ...
# 1915 2021-08-01  United Kingdom -1.596937 -0.586369 -1.596937  -1.010568
# 1916 2021-09-01  United Kingdom -2.022208 -0.521040 -2.022208  -1.501168
# 1917 2021-10-01  United Kingdom -2.193722 -0.440753 -2.193722  -1.752969
# 1918 2021-11-01  United Kingdom -1.539314 -0.763890 -1.539314  -0.775424
# 1919 2021-12-01  United Kingdom -1.574743 -0.950433 -1.574743  -0.624310
#
#       split       model model_group_name   group
# 0     train  linear_reg                   global
# 1     train  linear_reg                   global
# 2     train  linear_reg                   global
# 3     train  linear_reg                   global
# 4     train  linear_reg                   global
# ...     ...         ...              ...     ...
# 1915   test  linear_reg                   global
# 1916   test  linear_reg                   global
# 1917   test  linear_reg                   global
# 1918   test  linear_reg                   global
# 1919   test  linear_reg                   global
#
# [1920 rows x 10 columns]
#            country                       variable   coefficient  std_error  \
# 0          Algeria                      Intercept -7.532515e-16   0.080762
# 1          Algeria                          dubai  9.068070e-01   1.280867
# 2          Algeria                          brent -8.193715e-01   1.415654
# 3          Algeria                            wti -1.250121e-01   0.465231
# 4          Algeria  dubai_hydroskimming_singapore -1.756799e-02   0.113405
# ..             ...                            ...           ...        ...
# 65  United Kingdom                          dubai -4.105150e-01   1.012912
# 66  United Kingdom                            wti  5.116029e-01   0.283888
# 67  United Kingdom       urals_cracking_nw_europe  5.440687e-01   0.086759
# 68  United Kingdom   x50_50_hls_lls_cracking_usgc -6.308095e-01   0.158758
# 69  United Kingdom  tapis_hydroskimming_singapore -2.793535e-02   0.177978
#
#           t_stat       p_value         vif       model model_group_name  \
# 0  -9.326851e-15  1.000000e+00         NaN  linear_reg
# 1   7.079632e-01  4.801708e-01  251.535022  linear_reg
# 2  -5.787938e-01  5.636787e-01  307.258692  linear_reg
# 3  -2.687098e-01  7.885572e-01   33.183859  linear_reg
# 4  -1.549140e-01  8.771171e-01    1.971757  linear_reg
# ..           ...           ...         ...         ...              ...
# 65 -4.052822e-01  6.859023e-01  290.517127  linear_reg
# 66  1.802132e+00  7.372331e-02   22.820308  linear_reg
# 67  6.271041e+00  4.375420e-09    2.131361  linear_reg
# 68 -3.973402e+00  1.140476e-04    7.136740  linear_reg
# 69 -1.569594e-01  8.755079e-01    8.969379  linear_reg
#
#      group  ci_0.025  ci_0.975
# 0   global -0.159701  0.159701
# 1   global -1.626020  3.439634
# 2   global -3.618729  1.979986
# 3   global -1.044974  0.794950
# 4   global -0.241818  0.206682
# ..     ...       ...       ...
# 65  global -2.413478  1.592448
# 66  global -0.049765  1.072971
# 67  global  0.372509  0.715629
# 68  global -0.944742 -0.316876
# 69  global -0.379875  0.324004
#
# [70 rows x 12 columns]
#             country  split            metric                          value  \
# 0           Algeria  train              rmse                        0.94529
# 1           Algeria  train               mae                       0.694252
# 2           Algeria  train              mape                     347.555967
# 3           Algeria  train             smape                     141.755604
# 4           Algeria  train         r_squared                       0.106426
# ..              ...    ...               ...                            ...
# 255  United Kingdom               model_type                     linear_reg
# 256  United Kingdom              model_class               LinearRegression
# 257  United Kingdom  train       n_obs_train                            144
# 258  United Kingdom  train  train_start_date  2006-01-01T00:00:00.000000000
# 259  United Kingdom  train    train_end_date  2017-12-01T00:00:00.000000000
#
#           model model_group_name   group
# 0    linear_reg                   global
# 1    linear_reg                   global
# 2    linear_reg                   global
# 3    linear_reg                   global
# 4    linear_reg                   global
# ..          ...              ...     ...
# 255  linear_reg                   global
# 256  linear_reg                   global
# 257  linear_reg                   global
# 258  linear_reg                   global
# 259  linear_reg                   global
#
# [260 rows x 7 columns]
#            date         country     dubai     brent       wti  \
# 1430 2017-03-01  United Kingdom -1.014581 -1.057443 -1.112604
# 1431 2017-04-01  United Kingdom -0.964241 -1.019196 -1.048256
# 1432 2017-05-01  United Kingdom -1.047751 -1.099098 -1.159561
# 1433 2017-06-01  United Kingdom -1.198771 -1.249813 -1.304345
# 1434 2017-07-01  United Kingdom -1.152333 -1.181650 -1.239997
# 1435 2017-08-01  United Kingdom -1.043068 -1.080163 -1.179996
# 1436 2017-09-01  United Kingdom -0.909219 -0.936643 -1.101735
# 1437 2017-10-01  United Kingdom -0.842099 -0.843487 -1.026517
# 1438 2017-11-01  United Kingdom -0.646983 -0.656040 -0.805211
# 1439 2017-12-01  United Kingdom -0.614594 -0.593936 -0.749124
#
#       dubai_hydroskimming_singapore  x30_70_wcs_bakken_cracking_usmc  \
# 1430                            NaN                              NaN
# 1431                            NaN                              NaN
# 1432                            NaN                              NaN
# 1433                            NaN                              NaN
# 1434                            NaN                              NaN
# 1435                            NaN                              NaN
# 1436                            NaN                              NaN
# 1437                            NaN                              NaN
# 1438                            NaN                              NaN
# 1439                            NaN                              NaN
#
#       x50_50_hls_lls_cracking_usgc  refinery_kbd  urals_cracking_med  \
# 1430                      1.097357     -1.261554                 NaN
# 1431                      1.457779     -1.144334                 NaN
# 1432                      1.231228     -1.325671                 NaN
# 1433                      1.498971     -1.069161                 NaN
# 1434                      1.423454     -1.268952                 NaN
# 1435                      1.420021     -0.969327                 NaN
# 1436                      1.166009     -0.972327                 NaN
# 1437                      0.953188     -1.138251                 NaN
# 1438                      0.754098     -1.420820                 NaN
# 1439                      0.551575     -1.329370                 NaN
#
#       es_sider_hydroskimming_med  urals_hydroskimming_med  \
# 1430                         NaN                      NaN
# 1431                         NaN                      NaN
# 1432                         NaN                      NaN
# 1433                         NaN                      NaN
# 1434                         NaN                      NaN
# 1435                         NaN                      NaN
# 1436                         NaN                      NaN
# 1437                         NaN                      NaN
# 1438                         NaN                      NaN
# 1439                         NaN                      NaN
#
#       es_sider_cracking_med  urals_cracking_nw_europe  bakken_coking_usmc  \
# 1430                    NaN                 -0.052598                 NaN
# 1431                    NaN                  0.507125                 NaN
# 1432                    NaN                  0.094280                 NaN
# 1433                    NaN                  0.356277                 NaN
# 1434                    NaN                  0.407883                 NaN
# 1435                    NaN                  0.661942                 NaN
# 1436                    NaN                  1.277240                 NaN
# 1437                    NaN                  0.388035                 NaN
# 1438                    NaN                 -0.008932                 NaN
# 1439                    NaN                 -0.933864                 NaN
#
#       brent_hydroskimming_nw_europe  brent_cracking_nw_europe  \
# 1430                            NaN                       NaN
# 1431                            NaN                       NaN
# 1432                            NaN                       NaN
# 1433                            NaN                       NaN
# 1434                            NaN                       NaN
# 1435                            NaN                       NaN
# 1436                            NaN                       NaN
# 1437                            NaN                       NaN
# 1438                            NaN                       NaN
# 1439                            NaN                       NaN
#
#       tapis_hydroskimming_singapore  split
# 1430                       0.793128  train
# 1431                       1.134777  train
# 1432                       0.783177  train
# 1433                       0.886004  train
# 1434                       0.952343  train
# 1435                       1.204434  train
# 1436                       1.035268  train
# 1437                       0.829615  train
# 1438                       0.643864  train
# 1439                       0.534403  train
#         date  country     dubai     brent       wti  \
# 0 2018-01-01  Algeria -0.434697 -0.412926 -0.499991
# 1 2018-02-01  Algeria -0.560742 -0.548116 -0.565209
# 2 2018-03-01  Algeria -0.541230 -0.509111 -0.539557
# 3 2018-04-01  Algeria -0.340651 -0.312954 -0.384773
# 4 2018-05-01  Algeria -0.136559 -0.122856 -0.225642
# 5 2018-06-01  Algeria -0.153730 -0.178143 -0.332599
# 6 2018-07-01  Algeria -0.173241 -0.206545 -0.188250
# 7 2018-08-01  Algeria -0.196265 -0.256152 -0.312164
# 8 2018-09-01  Algeria -0.005442 -0.039167 -0.215642
# 9 2018-10-01  Algeria  0.070263  0.021800 -0.192163
#
#    dubai_hydroskimming_singapore  x30_70_wcs_bakken_cracking_usmc  \
# 0                       0.579561                        -0.184520
# 1                       1.048560                        -0.622057
# 2                       0.902313                        -0.448739
# 3                       0.297152                        -0.002719
# 4                       0.413141                         0.571775
# 5                       0.166034                         0.436030
# 6                       0.836754                         0.188779
# 7                       1.088904                         0.460270
# 8                       0.372797                         0.443302
# 9                       0.806496                         0.021522
#
#    x50_50_hls_lls_cracking_usgc  refinery_kbd  urals_cracking_med  \
# 0                      0.149961      0.798167                 NaN
# 1                      0.870806      1.123563                 NaN
# 2                      0.661418      1.235418                 NaN
# 3                      0.304428      1.520140                 NaN
# 4                      0.441732      0.289735                 NaN
# 5                      0.692311      0.198218                 NaN
# 6                      0.826182     -0.615273                 NaN
# 7                      1.430319      1.418453                 NaN
# 8                      0.520681      1.784524                 NaN
# 9                      0.342187      1.225249                 NaN
#
#    es_sider_hydroskimming_med  urals_hydroskimming_med  es_sider_cracking_med  \
# 0                         NaN                      NaN                    NaN
# 1                         NaN                      NaN                    NaN
# 2                         NaN                      NaN                    NaN
# 3                         NaN                      NaN                    NaN
# 4                         NaN                      NaN                    NaN
# 5                         NaN                      NaN                    NaN
# 6                         NaN                      NaN                    NaN
# 7                         NaN                      NaN                    NaN
# 8                         NaN                      NaN                    NaN
# 9                         NaN                      NaN                    NaN
#
#    urals_cracking_nw_europe  bakken_coking_usmc  \
# 0                       NaN                 NaN
# 1                       NaN                 NaN
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4                       NaN                 NaN
# 5                       NaN                 NaN
# 6                       NaN                 NaN
# 7                       NaN                 NaN
# 8                       NaN                 NaN
# 9                       NaN                 NaN
#
#    brent_hydroskimming_nw_europe  brent_cracking_nw_europe  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# 5                            NaN                       NaN
# 6                            NaN                       NaN
# 7                            NaN                       NaN
# 8                            NaN                       NaN
# 9                            NaN                       NaN
#
#    tapis_hydroskimming_singapore split
# 0                            NaN  test
# 1                            NaN  test
# 2                            NaN  test
# 3                            NaN  test
# 4                            NaN  test
# 5                            NaN  test
# 6                            NaN  test
# 7                            NaN  test
# 8                            NaN  test
# 9                            NaN  test
#                     bakken_coking_usmc  brent  brent_cracking_nw_europe  \
# Algeria                          False   True                     False
# Denmark                          False   True                     False
# Germany                          False  False                     False
# Italy                             True   True                     False
# Netherlands                      False  False                     False
# Norway                           False   True                     False
# Romania                          False   True                     False
# Russian Federation               False   True                     False
# Turkey                           False   True                      True
# United Kingdom                   False   True                     False
#
#                     brent_hydroskimming_nw_europe  dubai  \
# Algeria                                     False   True
# Denmark                                     False   True
# Germany                                     False   True
# Italy                                       False   True
# Netherlands                                 False   True
# Norway                                      False   True
# Romania                                      True   True
# Russian Federation                          False   True
# Turkey                                      False   True
# United Kingdom                              False   True
#
#                     dubai_hydroskimming_singapore  es_sider_cracking_med  \
# Algeria                                      True                  False
# Denmark                                     False                  False
# Germany                                     False                   True
# Italy                                       False                  False
# Netherlands                                 False                   True
# Norway                                      False                   True
# Romania                                     False                  False
# Russian Federation                          False                  False
# Turkey                                      False                   True
# United Kingdom                              False                  False
#
#                     es_sider_hydroskimming_med  tapis_hydroskimming_singapore  \
# Algeria                                  False                          False
# Denmark                                   True                          False
# Germany                                   True                          False
# Italy                                    False                          False
# Netherlands                               True                          False
# Norway                                   False                          False
# Romania                                  False                          False
# Russian Federation                       False                          False
# Turkey                                   False                           True
# United Kingdom                           False                           True
#
#                     urals_cracking_med  urals_cracking_nw_europe  \
# Algeria                          False                     False
# Denmark                           True                     False
# Germany                           True                      True
# Italy                             True                     False
# Netherlands                       True                     False
# Norway                            True                      True
# Romania                           True                      True
# Russian Federation                True                     False
# Turkey                           False                      True
# United Kingdom                   False                      True
#
#                     urals_hydroskimming_med    wti  \
# Algeria                               False   True
# Denmark                                True   True
# Germany                               False   True
# Italy                                 False   True
# Netherlands                           False   True
# Norway                                False   True
# Romania                               False   True
# Russian Federation                     True   True
# Turkey                                False  False
# United Kingdom                        False   True
#
#                     x30_70_wcs_bakken_cracking_usmc  \
# Algeria                                        True
# Denmark                                       False
# Germany                                       False
# Italy                                          True
# Netherlands                                   False
# Norway                                        False
# Romania                                       False
# Russian Federation                            False
# Turkey                                        False
# United Kingdom                                False
#
#                     x50_50_hls_lls_cracking_usgc
# Algeria                                     True
# Denmark                                    False
# Germany                                    False
# Italy                                      False
# Netherlands                                 True
# Norway                                     False
# Romania                                    False
# Russian Federation                          True
# Turkey                                     False
# United Kingdom                              True

# %% [markdown]
# # 26. Advanced Dimensionality Reduction
#
# ## ICA, Kernel PCA, and PLS
#
# Advanced methods for feature extraction and dimensionality reduction.

# %%
# Recipe with ICA (finds independent signals)
rec_ica = (
    recipe()
    .step_normalize(all_numeric_predictors())
    .step_ica(all_numeric_predictors(), num_comp=5)
)

# Workflow
wf_ica = (
    workflow()
    .add_recipe(rec_ica)
    .add_model(linear_reg().set_engine("sklearn"))
)

# Fit and evaluate
fit_ica = wf_ica.fit_nested(train_data, group_col='country', per_group_prep=True)
fit_ica = fit_ica.evaluate(test_data)

print("✓ ICA model fitted successfully!")

fit = fit_ica

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# ✓ ICA model fitted successfully!
#            date         country    actuals       fitted   forecast  \
# 0    2006-01-01         Algeria   450.0000   473.101782   450.0000
# 1    2006-02-01         Algeria   436.0000   462.481706   436.0000
# 2    2006-03-01         Algeria   429.0000   457.071074   429.0000
# 3    2006-04-01         Algeria   451.0000   455.323074   451.0000
# 4    2006-05-01         Algeria   369.0000   466.124077   369.0000
# ...         ...             ...        ...          ...        ...
# 1915 2021-08-01  United Kingdom  1027.1426  1271.447655  1027.1426
# 1916 2021-09-01  United Kingdom   943.2540  1237.562798   943.2540
# 1917 2021-10-01  United Kingdom   909.4213  1222.475816   909.4213
# 1918 2021-11-01  United Kingdom  1038.5093  1181.774049  1038.5093
# 1919 2021-12-01  United Kingdom  1031.5206  1162.149387  1031.5206
#
#        residuals  split       model model_group_name   group
# 0     -23.101782  train  linear_reg                   global
# 1     -26.481706  train  linear_reg                   global
# 2     -28.071074  train  linear_reg                   global
# 3      -4.323074  train  linear_reg                   global
# 4     -97.124077  train  linear_reg                   global
# ...          ...    ...         ...              ...     ...
# 1915 -244.305055   test  linear_reg                   global
# 1916 -294.308798   test  linear_reg                   global
# 1917 -313.054516   test  linear_reg                   global
# 1918 -143.264749   test  linear_reg                   global
# 1919 -130.628787   test  linear_reg                   global
#
# [1920 rows x 10 columns]
#                country   variable  coefficient  std_error      t_stat  \
# 0              Algeria  Intercept   490.506944   7.367874   66.573746
# 1              Algeria        IC1   -23.483354   7.367874   -3.187263
# 2              Algeria        IC2    -0.933196   7.367874   -0.126657
# 3              Algeria        IC3    -5.090938   7.367874   -0.690964
# 4              Algeria        IC4    -2.269815   7.367874   -0.308069
# 5              Algeria        IC5   -39.953314   7.367874   -5.422638
# 6              Denmark  Intercept   151.955490   1.453689  104.530984
# 7              Denmark        IC1    -0.802750   1.453689   -0.552216
# 8              Denmark        IC2    -2.053564   1.453689   -1.412658
# 9              Denmark        IC3    -4.097959   1.453689   -2.819007
# 10             Denmark        IC4     2.579758   1.453689    1.774629
# 11             Denmark        IC5     2.087145   1.453689    1.435758
# 12             Germany  Intercept  2011.021846   9.651388  208.366084
# 13             Germany        IC1    68.375566   9.651388    7.084532
# 14             Germany        IC2   -41.720708   9.651388   -4.322768
# 15             Germany        IC3   -48.093025   9.651388   -4.983017
# 16             Germany        IC4    77.435620   9.651388    8.023263
# 17             Germany        IC5    17.308225   9.651388    1.793341
# 18               Italy  Intercept  1531.737976  13.594603  112.672506
# 19               Italy        IC1    97.035853  13.594603    7.137822
# 20               Italy        IC2   -28.331999  13.594603   -2.084062
# 21               Italy        IC3   -98.508131  13.594603   -7.246120
# 22               Italy        IC4    79.060867  13.594603    5.815607
# 23               Italy        IC5    53.083944  13.594603    3.904781
# 24         Netherlands  Intercept  1018.838055   5.971905  170.605191
# 25         Netherlands        IC1   -29.123309   5.971905   -4.876720
# 26         Netherlands        IC2    -2.839616   5.971905   -0.475496
# 27         Netherlands        IC3    12.125532   5.971905    2.030429
# 28         Netherlands        IC4    11.246864   5.971905    1.883296
# 29         Netherlands        IC5    -4.733452   5.971905   -0.792620
# 30              Norway  Intercept   291.043278   3.368624   86.398259
# 31              Norway        IC1     9.102760   3.368624    2.702219
# 32              Norway        IC2    -1.646064   3.368624   -0.488646
# 33              Norway        IC3     4.938910   3.368624    1.466151
# 34              Norway        IC4     2.755192   3.368624    0.817898
# 35              Norway        IC5    -3.955511   3.368624   -1.174222
# 36             Romania  Intercept   226.101711   2.630156   85.965132
# 37             Romania        IC1     7.774959   2.630156    2.956083
# 38             Romania        IC2   -10.096348   2.630156   -3.838688
# 39             Romania        IC3   -12.014504   2.630156   -4.567982
# 40             Romania        IC4    18.093961   2.630156    6.879425
# 41             Romania        IC5     1.407094   2.630156    0.534985
# 42  Russian Federation  Intercept  5243.697673  27.477643  190.835063
# 43  Russian Federation        IC1  -264.842646  27.477643   -9.638478
# 44  Russian Federation        IC2    52.783445  27.477643    1.920960
# 45  Russian Federation        IC3   250.903170  27.477643    9.131175
# 46  Russian Federation        IC4  -157.333049  27.477643   -5.725857
# 47  Russian Federation        IC5  -119.155635  27.477643   -4.336458
# 48              Turkey  Intercept   461.271737   5.111637   90.239530
# 49              Turkey        IC1     3.539862   5.111637    0.692510
# 50              Turkey        IC2   -10.429970   5.111637   -2.040436
# 51              Turkey        IC3    11.150643   5.111637    2.181423
# 52              Turkey        IC4    48.298752   5.111637    9.448783
# 53              Turkey        IC5     5.166129   5.111637    1.010660
# 54      United Kingdom  Intercept  1342.153024  11.803781  113.705348
# 55      United Kingdom        IC1    99.827199  11.803781    8.457222
# 56      United Kingdom        IC2   -28.052428  11.803781   -2.376563
# 57      United Kingdom        IC3   -64.374060  11.803781   -5.453681
# 58      United Kingdom        IC4    15.430178  11.803781    1.307223
# 59      United Kingdom        IC5    67.447812  11.803781    5.714085
#
#          p_value  vif       model model_group_name   group     ci_0.025  \
# 0   0.000000e+00  NaN  linear_reg                   global   475.938422
# 1   1.776823e-03  1.0  linear_reg                   global   -38.051877
# 2   8.993959e-01  1.0  linear_reg                   global   -15.501719
# 3   4.907486e-01  1.0  linear_reg                   global   -19.659461
# 4   7.584942e-01  1.0  linear_reg                   global   -16.838338
# 5   2.552731e-07  1.0  linear_reg                   global   -54.521837
# 6   0.000000e+00  NaN  linear_reg                   global   149.081106
# 7   5.816937e-01  1.0  linear_reg                   global    -3.677133
# 8   1.600077e-01  1.0  linear_reg                   global    -4.927948
# 9   5.526363e-03  1.0  linear_reg                   global    -6.972342
# 10  7.816400e-02  1.0  linear_reg                   global    -0.294626
# 11  1.533340e-01  1.0  linear_reg                   global    -0.787238
# 12  0.000000e+00  NaN  linear_reg                   global  1991.938123
# 13  6.523049e-11  1.0  linear_reg                   global    49.291843
# 14  2.930757e-05  1.0  linear_reg                   global   -60.804431
# 15  1.843634e-06  1.0  linear_reg                   global   -67.176748
# 16  3.987921e-13  1.0  linear_reg                   global    58.351897
# 17  7.510853e-02  1.0  linear_reg                   global    -1.775498
# 18  0.000000e+00  NaN  linear_reg                   global  1504.857319
# 19  4.917489e-11  1.0  linear_reg                   global    70.155196
# 20  3.899830e-02  1.0  linear_reg                   global   -55.212655
# 21  2.761680e-11  1.0  linear_reg                   global  -125.388787
# 22  4.014644e-08  1.0  linear_reg                   global    52.180210
# 23  1.469833e-04  1.0  linear_reg                   global    26.203288
# 24  0.000000e+00  NaN  linear_reg                   global  1007.029785
# 25  2.927508e-06  1.0  linear_reg                   global   -40.931578
# 26  6.351854e-01  1.0  linear_reg                   global   -14.647886
# 27  4.423401e-02  1.0  linear_reg                   global     0.317262
# 28  6.176478e-02  1.0  linear_reg                   global    -0.561406
# 29  4.293598e-01  1.0  linear_reg                   global   -16.541721
# 30  0.000000e+00  NaN  linear_reg                   global   284.382485
# 31  7.752673e-03  1.0  linear_reg                   global     2.441967
# 32  6.258682e-01  1.0  linear_reg                   global    -8.306857
# 33  1.448822e-01  1.0  linear_reg                   global    -1.721882
# 34  4.148252e-01  1.0  linear_reg                   global    -3.905600
# 35  2.423286e-01  1.0  linear_reg                   global   -10.616304
# 36  0.000000e+00  NaN  linear_reg                   global   220.901094
# 37  3.665675e-03  1.0  linear_reg                   global     2.574342
# 38  1.876913e-04  1.0  linear_reg                   global   -15.296965
# 39  1.081169e-05  1.0  linear_reg                   global   -17.215121
# 40  1.918570e-10  1.0  linear_reg                   global    12.893344
# 41  5.935212e-01  1.0  linear_reg                   global    -3.793523
# 42  0.000000e+00  NaN  linear_reg                   global  5189.366033
# 43  0.000000e+00  1.0  linear_reg                   global  -319.174286
# 44  5.679897e-02  1.0  linear_reg                   global    -1.548195
# 45  8.881784e-16  1.0  linear_reg                   global   196.571530
# 46  6.165092e-08  1.0  linear_reg                   global  -211.664690
# 47  2.774755e-05  1.0  linear_reg                   global  -173.487275
# 48  0.000000e+00  NaN  linear_reg                   global   451.164479
# 49  4.897805e-01  1.0  linear_reg                   global    -6.567396
# 50  4.321392e-02  1.0  linear_reg                   global   -20.537228
# 51  3.084572e-02  1.0  linear_reg                   global     1.043385
# 52  0.000000e+00  1.0  linear_reg                   global    38.191494
# 53  3.139478e-01  1.0  linear_reg                   global    -4.941130
# 54  0.000000e+00  NaN  linear_reg                   global  1318.813366
# 55  3.508305e-14  1.0  linear_reg                   global    76.487541
# 56  1.884786e-02  1.0  linear_reg                   global   -51.392086
# 57  2.211717e-07  1.0  linear_reg                   global   -87.713718
# 58  1.933108e-01  1.0  linear_reg                   global    -7.909480
# 59  6.520080e-08  1.0  linear_reg                   global    44.108154
#
#        ci_0.975
# 0    505.075467
# 1     -8.914831
# 2     13.635326
# 3      9.477584
# 4     12.298707
# 5    -25.384791
# 6    154.829873
# 7      2.071634
# 8      0.820819
# 9     -1.223575
# 10     5.454141
# 11     4.961529
# 12  2030.105569
# 13    87.459289
# 14   -22.636985
# 15   -29.009302
# 16    96.519343
# 17    36.391947
# 18  1558.618632
# 19   123.916509
# 20    -1.451342
# 21   -71.627474
# 22   105.941523
# 23    79.964601
# 24  1030.646324
# 25   -17.315039
# 26     8.968653
# 27    23.933801
# 28    23.055133
# 29     7.074818
# 30   297.704071
# 31    15.763553
# 32     5.014729
# 33    11.599703
# 34     9.415985
# 35     2.705281
# 36   231.302328
# 37    12.975576
# 38    -4.895731
# 39    -6.813887
# 40    23.294577
# 41     6.607711
# 42  5298.029313
# 43  -210.511006
# 44   107.115086
# 45   305.234810
# 46  -103.001409
# 47   -64.823995
# 48   471.378995
# 49    13.647120
# 50    -0.322711
# 51    21.257902
# 52    58.406010
# 53    15.273387
# 54  1365.492682
# 55   123.166857
# 56    -4.712770
# 57   -41.034402
# 58    38.769836
# 59    90.787470
#             country  split            metric                          value  \
# 0           Algeria  train              rmse                      86.552917
# 1           Algeria  train               mae                       63.32577
# 2           Algeria  train              mape                      12.760989
# 3           Algeria  train             smape                      14.939782
# 4           Algeria  train         r_squared                       0.225381
# ..              ...    ...               ...                            ...
# 255  United Kingdom               model_type                     linear_reg
# 256  United Kingdom              model_class               LinearRegression
# 257  United Kingdom  train       n_obs_train                            144
# 258  United Kingdom  train  train_start_date  2006-01-01T00:00:00.000000000
# 259  United Kingdom  train    train_end_date  2017-12-01T00:00:00.000000000
#
#           model model_group_name   group
# 0    linear_reg                   global
# 1    linear_reg                   global
# 2    linear_reg                   global
# 3    linear_reg                   global
# 4    linear_reg                   global
# ..          ...              ...     ...
# 255  linear_reg                   global
# 256  linear_reg                   global
# 257  linear_reg                   global
# 258  linear_reg                   global
# 259  linear_reg                   global
#
# [260 rows x 7 columns]
#            date         country  refinery_kbd       IC1       IC2       IC3  \
# 1430 2017-03-01  United Kingdom     1093.3000 -1.141516  0.314402  0.139459
# 1431 2017-04-01  United Kingdom     1116.4227 -1.463619  0.137784  0.369469
# 1432 2017-05-01  United Kingdom     1080.6523 -1.463006  0.399611 -0.028197
# 1433 2017-06-01  United Kingdom     1131.2513 -1.769771  0.558252  0.183692
# 1434 2017-07-01  United Kingdom     1091.8406 -1.439938  0.659002  0.470319
# 1435 2017-08-01  United Kingdom     1150.9445 -1.177714  0.574443  0.880005
# 1436 2017-09-01  United Kingdom     1150.3527 -0.574368  0.708252  0.791737
# 1437 2017-10-01  United Kingdom     1117.6226 -0.600606  0.936919  0.836114
# 1438 2017-11-01  United Kingdom     1061.8833 -0.726265  0.761411  0.731577
# 1439 2017-12-01  United Kingdom     1079.9226 -0.579870  0.571814  0.887765
#
#            IC4       IC5  split
# 1430  0.572525 -0.489402  train
# 1431  0.565966  0.176313  train
# 1432  0.451818  0.141836  train
# 1433  0.669823  0.411606  train
# 1434  0.843864  0.470702  train
# 1435  0.959529  0.511135  train
# 1436  1.345762  0.947923  train
# 1437  0.765319  0.247745  train
# 1438  0.325860 -0.045733  train
# 1439  0.168780 -1.110631  train
#         date  country  refinery_kbd       IC1       IC2       IC3       IC4  \
# 0 2018-01-01  Algeria         569.0 -0.333641  0.387385  0.531656  0.016655
# 1 2018-02-01  Algeria         601.0 -0.682442 -0.109648  0.429548  0.541580
# 2 2018-03-01  Algeria         612.0 -0.454546  0.110086  0.479809  0.478843
# 3 2018-04-01  Algeria         640.0 -0.017433  0.166166  0.166914  0.420639
# 4 2018-05-01  Algeria         519.0 -0.213019  0.405843  0.502362  0.073177
# 5 2018-06-01  Algeria         510.0 -0.985049  0.355829  0.017734 -0.266134
# 6 2018-07-01  Algeria         430.0 -1.038936  0.313253  0.001786 -0.026776
# 7 2018-08-01  Algeria         630.0 -1.412204 -0.176683  0.517845  0.191691
# 8 2018-09-01  Algeria         666.0 -0.547742  0.291417  0.733654 -0.332087
# 9 2018-10-01  Algeria         611.0 -0.554627  0.621788  0.204911 -0.246861
#
#         IC5 split
# 0 -1.140184  test
# 1 -0.923453  test
# 2 -1.026394  test
# 3 -0.230757  test
# 4  0.065680  test
# 5  0.540435  test
# 6  0.642727  test
# 7  1.048572  test
# 8 -0.527052  test
# 9 -0.406675  test
#                      IC1   IC2   IC3   IC4   IC5
# Algeria             True  True  True  True  True
# Denmark             True  True  True  True  True
# Germany             True  True  True  True  True
# Italy               True  True  True  True  True
# Netherlands         True  True  True  True  True
# Norway              True  True  True  True  True
# Romania             True  True  True  True  True
# Russian Federation  True  True  True  True  True
# Turkey              True  True  True  True  True
# United Kingdom      True  True  True  True  True

# %%
# Recipe with Kernel PCA (non-linear dimensionality reduction)
rec_kpca = (
    recipe()
    .step_normalize(all_numeric_predictors())
    .step_kpca(all_numeric_predictors(), num_comp=5, kernel='rbf')
)

# Workflow
wf_kpca = (
    workflow()
    .add_recipe(rec_kpca)
    .add_model(linear_reg().set_engine("sklearn"))
)

# Fit and evaluate
fit_kpca = wf_kpca.fit_nested(train_data, group_col='country', per_group_prep=True)
fit_kpca = fit_kpca.evaluate(test_data)

print("✓ Kernel PCA model fitted successfully!")

fit = fit_kpca

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# ✓ Kernel PCA model fitted successfully!
#            date         country    actuals       fitted   forecast  \
# 0    2006-01-01         Algeria   450.0000   458.343524   450.0000
# 1    2006-02-01         Algeria   436.0000   464.392259   436.0000
# 2    2006-03-01         Algeria   429.0000   494.714518   429.0000
# 3    2006-04-01         Algeria   451.0000   470.366834   451.0000
# 4    2006-05-01         Algeria   369.0000   454.556015   369.0000
# ...         ...             ...        ...          ...        ...
# 1915 2021-08-01  United Kingdom  1027.1426  1317.274138  1027.1426
# 1916 2021-09-01  United Kingdom   943.2540  1265.732130   943.2540
# 1917 2021-10-01  United Kingdom   909.4213  1311.639186   909.4213
# 1918 2021-11-01  United Kingdom  1038.5093  1348.279999  1038.5093
# 1919 2021-12-01  United Kingdom  1031.5206  1262.138456  1031.5206
#
#        residuals  split       model model_group_name   group
# 0      -8.343524  train  linear_reg                   global
# 1     -28.392259  train  linear_reg                   global
# 2     -65.714518  train  linear_reg                   global
# 3     -19.366834  train  linear_reg                   global
# 4     -85.556015  train  linear_reg                   global
# ...          ...    ...         ...              ...     ...
# 1915 -290.131538   test  linear_reg                   global
# 1916 -322.478130   test  linear_reg                   global
# 1917 -402.217886   test  linear_reg                   global
# 1918 -309.770699   test  linear_reg                   global
# 1919 -230.617856   test  linear_reg                   global
#
# [1920 rows x 10 columns]
#                country   variable  coefficient   std_error      t_stat  \
# 0              Algeria  Intercept   490.506944    7.350504   66.731062
# 1              Algeria       KPC1    29.396653   19.595804    1.500150
# 2              Algeria       KPC2    42.929123   23.647932    1.815344
# 3              Algeria       KPC3   106.662817   31.029942    3.437416
# 4              Algeria       KPC4  -159.245242   33.097966   -4.811330
# 5              Algeria       KPC5    25.790098   37.057670    0.695945
# 6              Denmark  Intercept   151.955490    1.474974  103.022471
# 7              Denmark       KPC1     6.263565    3.932153    1.592910
# 8              Denmark       KPC2     6.367858    4.745265    1.341939
# 9              Denmark       KPC3    -0.186825    6.226561   -0.030005
# 10             Denmark       KPC4    16.637892    6.641537    2.505127
# 11             Denmark       KPC5     4.966679    7.436103    0.667914
# 12             Germany  Intercept  2011.021846    9.663780  208.098893
# 13             Germany       KPC1    36.304375   25.762795    1.409178
# 14             Germany       KPC2   123.621828   31.090167    3.976236
# 15             Germany       KPC3  -200.763094   40.795368   -4.921223
# 16             Germany       KPC4   367.716187   43.514220    8.450483
# 17             Germany       KPC5   334.376545   48.720082    6.863218
# 18               Italy  Intercept  1531.737976   13.557656  112.979555
# 19               Italy       KPC1   -31.049254   36.143531   -0.859054
# 20               Italy       KPC2   246.929231   43.617489    5.661244
# 21               Italy       KPC3  -290.477335   57.233257   -5.075324
# 22               Italy       KPC4   563.480856   61.047629    9.230184
# 23               Italy       KPC5   262.357064   68.351116    3.838373
# 24         Netherlands  Intercept  1018.838055    5.934793  171.672041
# 25         Netherlands       KPC1    68.508953   15.821642    4.330079
# 26         Netherlands       KPC2    27.460675   19.093328    1.438234
# 27         Netherlands       KPC3    -0.122943   25.053559   -0.004907
# 28         Netherlands       KPC4   -96.037895   26.723280   -3.593791
# 29         Netherlands       KPC5   -25.199686   29.920344   -0.842226
# 30              Norway  Intercept   291.043278    3.363832   86.521338
# 31              Norway       KPC1    -6.747669    8.967684   -0.752443
# 32              Norway       KPC2   -16.856379   10.822071   -1.557593
# 33              Norway       KPC3   -19.096844   14.200322   -1.344818
# 34              Norway       KPC4     5.292578   15.146718    0.349421
# 35              Norway       KPC5    45.638230   16.958809    2.691122
# 36             Romania  Intercept   226.101711    2.694929   83.898945
# 37             Romania       KPC1    22.314539    7.184446    3.105951
# 38             Romania       KPC2    28.528653    8.670086    3.290470
# 39             Romania       KPC3    -6.132963   11.376566   -0.539087
# 40             Romania       KPC4    65.133280   12.134770    5.367492
# 41             Romania       KPC5    76.202477   13.586523    5.608681
# 42  Russian Federation  Intercept  5243.697673   31.531933  166.298009
# 43  Russian Federation       KPC1   182.546226   84.061386    2.171582
# 44  Russian Federation       KPC2  -537.967190  101.444063   -5.303092
# 45  Russian Federation       KPC3   620.177473  133.111148    4.659095
# 46  Russian Federation       KPC4 -1276.943868  141.982486   -8.993672
# 47  Russian Federation       KPC5  -426.645427  158.968686   -2.683833
# 48              Turkey  Intercept   461.271737    5.016122   91.957846
# 49              Turkey       KPC1   114.678846   13.372543    8.575695
# 50              Turkey       KPC2    -8.097450   16.137791   -0.501769
# 51              Turkey       KPC3   -25.716133   21.175413   -1.214434
# 52              Turkey       KPC4    23.955241   22.586672    1.060592
# 53              Turkey       KPC5   144.051460   25.288848    5.696244
# 54      United Kingdom  Intercept  1342.153024   12.354365  108.637963
# 55      United Kingdom       KPC1  -141.104763   32.935660   -4.284255
# 56      United Kingdom       KPC2    59.440773   39.746278    1.495505
# 57      United Kingdom       KPC3  -287.413749   52.153596   -5.510910
# 58      United Kingdom       KPC4   446.572068   55.629429    8.027623
# 59      United Kingdom       KPC5    77.118856   62.284705    1.238167
#
#          p_value  vif       model model_group_name   group     ci_0.025  \
# 0   0.000000e+00  NaN  linear_reg                   global   475.972767
# 1   1.358598e-01  1.0  linear_reg                   global    -9.350199
# 2   7.164237e-02  1.0  linear_reg                   global    -3.830017
# 3   7.765754e-04  1.0  linear_reg                   global    45.307204
# 4   3.878521e-06  1.0  linear_reg                   global  -224.689967
# 5   4.876337e-01  1.0  linear_reg                   global   -47.484165
# 6   0.000000e+00  NaN  linear_reg                   global   149.039018
# 7   1.134684e-01  1.0  linear_reg                   global    -1.511495
# 8   1.818194e-01  1.0  linear_reg                   global    -3.014971
# 9   9.761068e-01  1.0  linear_reg                   global   -12.498627
# 10  1.340368e-02  1.0  linear_reg                   global     3.505556
# 11  5.053039e-01  1.0  linear_reg                   global    -9.736755
# 12  0.000000e+00  NaN  linear_reg                   global  1991.913620
# 13  1.610318e-01  1.0  linear_reg                   global   -14.636490
# 14  1.124745e-04  1.0  linear_reg                   global    62.147130
# 15  2.414089e-06  1.0  linear_reg                   global  -281.427920
# 16  3.641532e-14  1.0  linear_reg                   global   281.675366
# 17  2.088030e-10  1.0  linear_reg                   global   238.042155
# 18  0.000000e+00  NaN  linear_reg                   global  1504.930374
# 19  3.918003e-01  1.0  linear_reg                   global  -102.515985
# 20  8.376150e-08  1.0  linear_reg                   global   160.684215
# 21  1.227672e-06  1.0  linear_reg                   global  -403.644856
# 22  4.440892e-16  1.0  linear_reg                   global   442.771162
# 23  1.879087e-04  1.0  linear_reg                   global   127.206160
# 24  0.000000e+00  NaN  linear_reg                   global  1007.103167
# 25  2.846427e-05  1.0  linear_reg                   global    37.224766
# 26  1.526316e-01  1.0  linear_reg                   global   -10.292630
# 27  9.960917e-01  1.0  linear_reg                   global   -49.661433
# 28  4.524987e-04  1.0  linear_reg                   global  -148.877932
# 29  4.011188e-01  1.0  linear_reg                   global   -84.361288
# 30  0.000000e+00  NaN  linear_reg                   global   284.391960
# 31  4.530664e-01  1.0  linear_reg                   global   -24.479503
# 32  1.216202e-01  1.0  linear_reg                   global   -38.254898
# 33  1.808902e-01  1.0  linear_reg                   global   -47.175191
# 34  7.273061e-01  1.0  linear_reg                   global   -24.657080
# 35  8.001729e-03  1.0  linear_reg                   global    12.105518
# 36  0.000000e+00  NaN  linear_reg                   global   220.773018
# 37  2.302639e-03  1.0  linear_reg                   global     8.108708
# 38  1.269760e-03  1.0  linear_reg                   global    11.385261
# 39  5.906952e-01  1.0  linear_reg                   global   -28.627887
# 40  3.289387e-07  1.0  linear_reg                   global    41.139157
# 41  1.073221e-07  1.0  linear_reg                   global    49.337796
# 42  0.000000e+00  NaN  linear_reg                   global  5181.349470
# 43  3.159640e-02  1.0  linear_reg                   global    16.331350
# 44  4.414195e-07  1.0  linear_reg                   global  -738.552895
# 45  7.395331e-06  1.0  linear_reg                   global   356.976328
# 46  1.776357e-15  1.0  linear_reg                   global -1557.686341
# 47  8.169252e-03  1.0  linear_reg                   global  -740.974772
# 48  0.000000e+00  NaN  linear_reg                   global   451.353342
# 49  1.798561e-14  1.0  linear_reg                   global    88.237269
# 50  6.166293e-01  1.0  linear_reg                   global   -40.006762
# 51  2.266562e-01  1.0  linear_reg                   global   -67.586352
# 52  2.907281e-01  1.0  linear_reg                   global   -20.705464
# 53  7.096561e-08  1.0  linear_reg                   global    94.047732
# 54  0.000000e+00  NaN  linear_reg                   global  1317.724694
# 55  3.416142e-05  1.0  linear_reg                   global  -206.228561
# 56  1.370659e-01  1.0  linear_reg                   global   -19.149683
# 57  1.695811e-07  1.0  linear_reg                   global  -390.537239
# 58  3.892442e-13  1.0  linear_reg                   global   336.575801
# 59  2.177564e-01  1.0  linear_reg                   global   -46.036912
#
#        ci_0.975
# 0    505.041122
# 1     68.143505
# 2     89.688262
# 3    168.018431
# 4    -93.800516
# 5     99.064361
# 6    154.871961
# 7     14.038625
# 8     15.750688
# 9     12.124977
# 10    29.770227
# 11    19.670113
# 12  2030.130072
# 13    87.245240
# 14   185.096526
# 15  -120.098269
# 16   453.757008
# 17   430.710935
# 18  1558.545578
# 19    40.417478
# 20   333.174247
# 21  -177.309814
# 22   684.190550
# 23   397.507968
# 24  1030.572942
# 25    99.793141
# 26    65.213980
# 27    49.415547
# 28   -43.197858
# 29    33.961915
# 30   297.694595
# 31    10.984165
# 32     4.542141
# 33     8.981502
# 34    35.242237
# 35    79.170942
# 36   231.430404
# 37    36.520371
# 38    45.672044
# 39    16.361961
# 40    89.127402
# 41   103.067158
# 42  5306.045876
# 43   348.761103
# 44  -337.381485
# 45   883.378618
# 46  -996.201396
# 47  -112.316082
# 48   471.190132
# 49   141.120422
# 50    23.811862
# 51    16.154086
# 52    68.615947
# 53   194.055188
# 54  1366.581353
# 55   -75.980966
# 56   138.031229
# 57  -184.290259
# 58   556.568335
# 59   200.274623
#             country  split            metric                          value  \
# 0           Algeria  train              rmse                      86.348872
# 1           Algeria  train               mae                       59.85092
# 2           Algeria  train              mape                      11.920365
# 3           Algeria  train             smape                      14.107512
# 4           Algeria  train         r_squared                       0.229029
# ..              ...    ...               ...                            ...
# 255  United Kingdom               model_type                     linear_reg
# 256  United Kingdom              model_class               LinearRegression
# 257  United Kingdom  train       n_obs_train                            144
# 258  United Kingdom  train  train_start_date  2006-01-01T00:00:00.000000000
# 259  United Kingdom  train    train_end_date  2017-12-01T00:00:00.000000000
#
#           model model_group_name   group
# 0    linear_reg                   global
# 1    linear_reg                   global
# 2    linear_reg                   global
# 3    linear_reg                   global
# 4    linear_reg                   global
# ..          ...              ...     ...
# 255  linear_reg                   global
# 256  linear_reg                   global
# 257  linear_reg                   global
# 258  linear_reg                   global
# 259  linear_reg                   global
#
# [260 rows x 7 columns]
#            date         country  refinery_kbd      KPC1      KPC2      KPC3  \
# 1430 2017-03-01  United Kingdom     1093.3000  0.541806  0.203555  0.080398
# 1431 2017-04-01  United Kingdom     1116.4227  0.670843 -0.160706  0.216901
# 1432 2017-05-01  United Kingdom     1080.6523  0.611374  0.010715  0.160842
# 1433 2017-06-01  United Kingdom     1131.2513  0.621244 -0.206915  0.319672
# 1434 2017-07-01  United Kingdom     1091.8406  0.624361 -0.264452  0.311305
# 1435 2017-08-01  United Kingdom     1150.9445  0.600321 -0.339540  0.291206
# 1436 2017-09-01  United Kingdom     1150.3527  0.510990 -0.372107  0.258227
# 1437 2017-10-01  United Kingdom     1117.6226  0.599273 -0.173642  0.066617
# 1438 2017-11-01  United Kingdom     1061.8833  0.490691  0.007920 -0.096066
# 1439 2017-12-01  United Kingdom     1079.9226  0.159857  0.270292 -0.124411
#
#           KPC4      KPC5  split
# 1430 -0.347199 -0.009635  train
# 1431 -0.140518 -0.088593  train
# 1432 -0.229154 -0.098052  train
# 1433 -0.106651 -0.112821  train
# 1434 -0.055784 -0.107188  train
# 1435  0.042259 -0.106537  train
# 1436  0.165957 -0.083970  train
# 1437 -0.139647 -0.079865  train
# 1438 -0.273868 -0.097656  train
# 1439 -0.395482  0.002691  train
#         date  country  refinery_kbd      KPC1      KPC2      KPC3      KPC4  \
# 0 2018-01-01  Algeria         569.0 -0.060257  0.358340 -0.116427 -0.320165
# 1 2018-02-01  Algeria         601.0  0.361759  0.270436 -0.067277 -0.305869
# 2 2018-03-01  Algeria         612.0  0.240949  0.313905 -0.109300 -0.315981
# 3 2018-04-01  Algeria         640.0  0.232445  0.268114 -0.304309 -0.220028
# 4 2018-05-01  Algeria         519.0  0.226017  0.083979 -0.367538 -0.230104
# 5 2018-06-01  Algeria         510.0  0.329209  0.069737 -0.230128 -0.144188
# 6 2018-07-01  Algeria         430.0  0.451736 -0.011954 -0.120748 -0.107227
# 7 2018-08-01  Algeria         630.0  0.542326 -0.357070  0.124298  0.168177
# 8 2018-09-01  Algeria         666.0  0.011121  0.168400 -0.298454 -0.335479
# 9 2018-10-01  Algeria         611.0 -0.012307  0.288337 -0.185197 -0.263291
#
#        KPC5 split
# 0  0.014640  test
# 1  0.103425  test
# 2  0.104375  test
# 3  0.095041  test
# 4 -0.065491  test
# 5 -0.209149  test
# 6 -0.171109  test
# 7 -0.168339  test
# 8 -0.093600  test
# 9 -0.143964  test
#                     KPC1  KPC2  KPC3  KPC4  KPC5
# Algeria             True  True  True  True  True
# Denmark             True  True  True  True  True
# Germany             True  True  True  True  True
# Italy               True  True  True  True  True
# Netherlands         True  True  True  True  True
# Norway              True  True  True  True  True
# Romania             True  True  True  True  True
# Russian Federation  True  True  True  True  True
# Turkey              True  True  True  True  True
# United Kingdom      True  True  True  True  True

# %%
# Recipe with PLS (supervised dimensionality reduction)
rec_pls = (
    recipe()
    .step_normalize(all_numeric_predictors())
    .step_pls(all_numeric_predictors(), outcome="refinery_kbd", num_comp=5)
)

# Workflow
wf_pls = (
    workflow()
    .add_recipe(rec_pls)
    .add_model(linear_reg().set_engine("sklearn"))
)

# Fit and evaluate
fit_pls = wf_pls.fit_nested(train_data, group_col='country', per_group_prep=True)
fit_pls = fit_pls.evaluate(test_data)

print("✓ PLS model fitted successfully!")

fit = fit_pls

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# ✓ PLS model fitted successfully!
#            date         country    actuals       fitted   forecast  \
# 0    2006-01-01         Algeria   450.0000   442.990798   450.0000
# 1    2006-02-01         Algeria   436.0000   467.688053   436.0000
# 2    2006-03-01         Algeria   429.0000   467.902732   429.0000
# 3    2006-04-01         Algeria   451.0000   443.593545   451.0000
# 4    2006-05-01         Algeria   369.0000   500.903187   369.0000
# ...         ...             ...        ...          ...        ...
# 1915 2021-08-01  United Kingdom  1027.1426  1076.473114  1027.1426
# 1916 2021-09-01  United Kingdom   943.2540  1086.384107   943.2540
# 1917 2021-10-01  United Kingdom   909.4213   996.586780   909.4213
# 1918 2021-11-01  United Kingdom  1038.5093   880.309527  1038.5093
# 1919 2021-12-01  United Kingdom  1031.5206   762.829420  1031.5206
#
#        residuals  split       model model_group_name   group
# 0       7.009202  train  linear_reg                   global
# 1     -31.688053  train  linear_reg                   global
# 2     -38.902732  train  linear_reg                   global
# 3       7.406455  train  linear_reg                   global
# 4    -131.903187  train  linear_reg                   global
# ...          ...    ...         ...              ...     ...
# 1915  -49.330514   test  linear_reg                   global
# 1916 -143.130107   test  linear_reg                   global
# 1917  -87.165480   test  linear_reg                   global
# 1918  158.199773   test  linear_reg                   global
# 1919  268.691180   test  linear_reg                   global
#
# [1920 rows x 10 columns]
#             country                         variable  coefficient   std_error  \
# 0           Algeria                        Intercept   490.506944    6.859131
# 1           Algeria                            brent  -571.392054  255.374829
# 2           Algeria                            dubai   296.066341  252.167916
# 3           Algeria                              wti   237.869652   95.165293
# 4           Algeria         brent_cracking_nw_europe  -214.524964  120.260818
# ..              ...                              ...          ...         ...
# 175  United Kingdom    dubai_hydroskimming_singapore   145.137232   42.472072
# 176  United Kingdom    tapis_hydroskimming_singapore    32.121054   43.603549
# 177  United Kingdom     x50_50_hls_lls_cracking_usgc   -60.306191   42.357870
# 178  United Kingdom  x30_70_wcs_bakken_cracking_usmc  1301.429852  356.774923
# 179  United Kingdom               bakken_coking_usmc -1183.489832  334.697572
#
#         t_stat   p_value          vif       model model_group_name   group  \
# 0    71.511527  0.000000          NaN  linear_reg                   global
# 1    -2.237464  0.027013  1386.174670  linear_reg                   global
# 2     1.174084  0.242576  1351.579010  linear_reg                   global
# 3     2.499542  0.013721   192.494779  linear_reg                   global
# 4    -1.783831  0.076858   307.404407  linear_reg                   global
# ..         ...       ...          ...         ...              ...     ...
# 175   3.417239  0.000852    23.894469  linear_reg                   global
# 176   0.736661  0.462698    25.184548  linear_reg                   global
# 177  -1.423730  0.156996    23.766143  linear_reg                   global
# 178   3.647762  0.000386  1686.083705  linear_reg                   global
# 179  -3.535998  0.000569  1483.869178  linear_reg                   global
#
#         ci_0.025     ci_0.975
# 0     476.932925   504.080963
# 1   -1076.771334   -66.012774
# 2    -202.966552   795.099234
# 3      49.540335   426.198968
# 4    -452.517588    23.467660
# ..           ...          ...
# 175    61.086251   229.188213
# 176   -54.169087   118.411195
# 177  -144.131170    23.518789
# 178   595.382768  2007.476935
# 179 -1845.846487  -521.133176
#
# [180 rows x 12 columns]
#             country  split            metric                          value  \
# 0           Algeria  train              rmse                      76.993557
# 1           Algeria  train               mae                      54.947692
# 2           Algeria  train              mape                      11.173539
# 3           Algeria  train             smape                      13.515596
# 4           Algeria  train         r_squared                       0.387038
# ..              ...    ...               ...                            ...
# 255  United Kingdom               model_type                     linear_reg
# 256  United Kingdom              model_class               LinearRegression
# 257  United Kingdom  train       n_obs_train                            144
# 258  United Kingdom  train  train_start_date  2006-01-01T00:00:00.000000000
# 259  United Kingdom  train    train_end_date  2017-12-01T00:00:00.000000000
#
#           model model_group_name   group
# 0    linear_reg                   global
# 1    linear_reg                   global
# 2    linear_reg                   global
# 3    linear_reg                   global
# 4    linear_reg                   global
# ..          ...              ...     ...
# 255  linear_reg                   global
# 256  linear_reg                   global
# 257  linear_reg                   global
# 258  linear_reg                   global
# 259  linear_reg                   global
#
# [260 rows x 7 columns]
#            date         country  refinery_kbd     brent     dubai       wti  \
# 1430 2017-03-01  United Kingdom     1093.3000 -1.057443 -1.014581 -1.112604
# 1431 2017-04-01  United Kingdom     1116.4227 -1.019196 -0.964241 -1.048256
# 1432 2017-05-01  United Kingdom     1080.6523 -1.099098 -1.047751 -1.159561
# 1433 2017-06-01  United Kingdom     1131.2513 -1.249813 -1.198771 -1.304345
# 1434 2017-07-01  United Kingdom     1091.8406 -1.181650 -1.152333 -1.239997
# 1435 2017-08-01  United Kingdom     1150.9445 -1.080163 -1.043068 -1.179996
# 1436 2017-09-01  United Kingdom     1150.3527 -0.936643 -0.909219 -1.101735
# 1437 2017-10-01  United Kingdom     1117.6226 -0.843487 -0.842099 -1.026517
# 1438 2017-11-01  United Kingdom     1061.8833 -0.656040 -0.646983 -0.805211
# 1439 2017-12-01  United Kingdom     1079.9226 -0.593936 -0.614594 -0.749124
#
#       brent_cracking_nw_europe  brent_hydroskimming_nw_europe  \
# 1430                 -0.311597                       0.378881
# 1431                  0.519328                       1.098069
# 1432                  0.245165                       1.007605
# 1433                  0.637429                       1.563958
# 1434                  0.734440                       1.532296
# 1435                  1.152011                       1.654422
# 1436                  1.312291                       1.631806
# 1437                  0.363266                       0.917141
# 1438                  0.329523                       0.690981
# 1439                 -0.488748                      -0.123194
#
#       urals_cracking_nw_europe  urals_hydroskimming_nw_europe  ...  \
# 1430                 -0.052598                       0.769716  ...
# 1431                  0.507125                       1.207120  ...
# 1432                  0.094280                       0.932051  ...
# 1433                  0.356277                       1.477679  ...
# 1434                  0.407883                       1.608449  ...
# 1435                  0.661942                       1.594921  ...
# 1436                  1.277240                       2.059381  ...
# 1437                  0.388035                       1.283778  ...
# 1438                 -0.008932                       0.688548  ...
# 1439                 -0.933864                      -0.321540  ...
#
#       es_sider_hydroskimming_med  urals_cracking_med  urals_hydroskimming_med  \
# 1430                    0.767560           -0.131079                 1.016494
# 1431                    1.454312            0.158431                 1.270942
# 1432                    1.286916            0.058354                 1.364239
# 1433                    1.797689            0.133412                 1.792559
# 1434                    1.621708            0.340715                 1.834967
# 1435                    1.492942            0.433644                 1.639891
# 1436                    1.359884            0.912586                 1.970672
# 1437                    0.844819            0.144134                 1.186126
# 1438                    0.613040           -0.356253                 0.562730
# 1439                   -0.005037           -0.677930                 0.066557
#
#       dubai_cracking_singapore  dubai_hydroskimming_singapore  \
# 1430                  0.008706                       0.635034
# 1431                  0.195133                       0.801453
# 1432                 -0.326861                       0.534173
# 1433                  0.143865                       1.341055
# 1434                  0.507397                       1.608334
# 1435                  0.945498                       1.764667
# 1436                  1.257762                       2.011775
# 1437                  0.600610                       1.361227
# 1438                  0.251061                       1.119162
# 1439                  0.381559                       1.063689
#
#       tapis_hydroskimming_singapore  x50_50_hls_lls_cracking_usgc  \
# 1430                       0.793128                      1.097357
# 1431                       1.134777                      1.457779
# 1432                       0.783177                      1.231228
# 1433                       0.886004                      1.498971
# 1434                       0.952343                      1.423454
# 1435                       1.204434                      1.420021
# 1436                       1.035268                      1.166009
# 1437                       0.829615                      0.953188
# 1438                       0.643864                      0.754098
# 1439                       0.534403                      0.551575
#
#       x30_70_wcs_bakken_cracking_usmc  bakken_coking_usmc  split
# 1430                        -0.332386           -0.356835  train
# 1431                         0.038490            0.043274  train
# 1432                        -0.077863           -0.102004  train
# 1433                        -0.077863           -0.122247  train
# 1434                         0.181507            0.139729  train
# 1435                         0.473602            0.470771  train
# 1436                         0.597227            0.602950  train
# 1437                         0.731761            0.768472  train
# 1438                         0.540263            0.533884  train
# 1439                         0.055458            0.045656  train
#
# [10 rows x 21 columns]
#         date  country  refinery_kbd     brent     dubai       wti  \
# 0 2018-01-01  Algeria         569.0 -0.412926 -0.434697 -0.499991
# 1 2018-02-01  Algeria         601.0 -0.548116 -0.560742 -0.565209
# 2 2018-03-01  Algeria         612.0 -0.509111 -0.541230 -0.539557
# 3 2018-04-01  Algeria         640.0 -0.312954 -0.340651 -0.384773
# 4 2018-05-01  Algeria         519.0 -0.122856 -0.136559 -0.225642
# 5 2018-06-01  Algeria         510.0 -0.178143 -0.153730 -0.332599
# 6 2018-07-01  Algeria         430.0 -0.206545 -0.173241 -0.188250
# 7 2018-08-01  Algeria         630.0 -0.256152 -0.196265 -0.312164
# 8 2018-09-01  Algeria         666.0 -0.039167 -0.005442 -0.215642
# 9 2018-10-01  Algeria         611.0  0.021800  0.070263 -0.192163
#
#    brent_cracking_nw_europe  brent_hydroskimming_nw_europe  \
# 0                 -0.615285                      -0.394586
# 1                 -0.290507                      -0.014638
# 2                 -0.948498                      -0.521236
# 3                 -0.286289                      -0.394586
# 4                 -0.117574                      -0.068916
# 5                  0.046924                       0.442205
# 6                  0.055360                       0.532669
# 7                  1.033910                       1.297089
# 8                 -0.429698                      -0.245321
# 9                 -1.281711                      -0.381016
#
#    urals_cracking_nw_europe  urals_hydroskimming_nw_europe  ...  \
# 0                 -1.001348                      -0.569552  ...
# 1                 -0.239172                       0.404461  ...
# 2                 -0.540867                       0.246635  ...
# 3                  0.086340                       0.368386  ...
# 4                 -0.004962                       0.417989  ...
# 5                  0.094280                       0.832846  ...
# 6                  0.300702                       1.229667  ...
# 7                  0.753244                       1.428077  ...
# 8                 -0.552776                      -0.055490  ...
# 9                 -0.588503                       0.666002  ...
#
#    es_sider_hydroskimming_med  urals_cracking_med  urals_hydroskimming_med  \
# 0                   -0.292615           -0.774433                -0.251503
# 1                   -0.056544           -0.009556                 0.774769
# 2                    0.029300           -0.002408                 0.711157
# 3                    0.115144            0.119115                 0.503358
# 4                    0.308294           -0.052446                 0.482154
# 5                    0.939248           -0.220433                 0.656027
# 6                    1.063722            0.097670                 1.181885
# 7                    1.801981            0.744599                 1.699262
# 8                    0.076515           -0.660059                -0.103075
# 9                   -0.017914           -0.502795                 0.376135
#
#    dubai_cracking_singapore  dubai_hydroskimming_singapore  \
# 0                  0.162508                       0.579561
# 1                  0.558664                       1.048560
# 2                  0.512057                       0.902313
# 3                  0.125223                       0.297152
# 4                  0.022688                       0.413141
# 5                 -0.690392                       0.166034
# 6                 -0.387449                       0.836754
# 7                  0.227757                       1.088904
# 8                 -0.075185                       0.372797
# 9                 -0.261612                       0.806496
#
#    tapis_hydroskimming_singapore  x50_50_hls_lls_cracking_usgc  \
# 0                       0.282312                      0.149961
# 1                       0.876053                      0.870806
# 2                       0.637230                      0.661418
# 3                       0.332067                      0.304428
# 4                       0.375188                      0.441732
# 5                       0.335384                      0.692311
# 6                       0.375188                      0.826182
# 7                       1.148045                      1.430319
# 8                       0.474697                      0.520681
# 9                       0.000369                      0.342187
#
#    x30_70_wcs_bakken_cracking_usmc  bakken_coking_usmc  split
# 0                        -0.184520           -0.171070   test
# 1                        -0.622057           -0.628337   test
# 2                        -0.448739           -0.458053   test
# 3                        -0.002719            0.008741   test
# 4                         0.571775            0.599378   test
# 5                         0.436030            0.435047   test
# 6                         0.188779            0.140920   test
# 7                         0.460270            0.439811   test
# 8                         0.443302            0.458863   test
# 9                         0.021522           -0.025792   test
#
# [10 rows x 21 columns]
#                     bakken_coking_usmc  brent  brent_cracking_nw_europe  \
# Algeria                           True   True                      True
# Denmark                           True   True                      True
# Germany                           True   True                      True
# Italy                             True   True                      True
# Netherlands                       True   True                      True
# Norway                            True   True                      True
# Romania                           True   True                      True
# Russian Federation                True   True                      True
# Turkey                            True   True                      True
# United Kingdom                    True   True                      True
#
#                     brent_hydroskimming_nw_europe  dubai  \
# Algeria                                      True   True
# Denmark                                      True   True
# Germany                                      True   True
# Italy                                        True   True
# Netherlands                                  True   True
# Norway                                       True   True
# Romania                                      True   True
# Russian Federation                           True   True
# Turkey                                       True   True
# United Kingdom                               True   True
#
#                     dubai_cracking_singapore  dubai_hydroskimming_singapore  \
# Algeria                                 True                           True
# Denmark                                 True                           True
# Germany                                 True                           True
# Italy                                   True                           True
# Netherlands                             True                           True
# Norway                                  True                           True
# Romania                                 True                           True
# Russian Federation                      True                           True
# Turkey                                  True                           True
# United Kingdom                          True                           True
#
#                     es_sider_cracking_med  es_sider_hydroskimming_med  \
# Algeria                              True                        True
# Denmark                              True                        True
# Germany                              True                        True
# Italy                                True                        True
# Netherlands                          True                        True
# Norway                               True                        True
# Romania                              True                        True
# Russian Federation                   True                        True
# Turkey                               True                        True
# United Kingdom                       True                        True
#
#                     tapis_hydroskimming_singapore  urals_cracking_med  \
# Algeria                                      True                True
# Denmark                                      True                True
# Germany                                      True                True
# Italy                                        True                True
# Netherlands                                  True                True
# Norway                                       True                True
# Romania                                      True                True
# Russian Federation                           True                True
# Turkey                                       True                True
# United Kingdom                               True                True
#
#                     urals_cracking_nw_europe  urals_hydroskimming_med  \
# Algeria                                 True                     True
# Denmark                                 True                     True
# Germany                                 True                     True
# Italy                                   True                     True
# Netherlands                             True                     True
# Norway                                  True                     True
# Romania                                 True                     True
# Russian Federation                      True                     True
# Turkey                                  True                     True
# United Kingdom                          True                     True
#
#                     urals_hydroskimming_nw_europe   wti  \
# Algeria                                      True  True
# Denmark                                      True  True
# Germany                                      True  True
# Italy                                        True  True
# Netherlands                                  True  True
# Norway                                       True  True
# Romania                                      True  True
# Russian Federation                           True  True
# Turkey                                       True  True
# United Kingdom                               True  True
#
#                     x30_70_wcs_bakken_cracking_usmc  \
# Algeria                                        True
# Denmark                                        True
# Germany                                        True
# Italy                                          True
# Netherlands                                    True
# Norway                                         True
# Romania                                        True
# Russian Federation                             True
# Turkey                                         True
# United Kingdom                                 True
#
#                     x50_50_hls_lls_cracking_usgc
# Algeria                                     True
# Denmark                                     True
# Germany                                     True
# Italy                                       True
# Netherlands                                 True
# Norway                                      True
# Romania                                     True
# Russian Federation                          True
# Turkey                                      True
# United Kingdom                              True

# %% [markdown]
# ---
#
# # Feature Selection with Per-Group Preprocessing
#
# This section demonstrates how different feature selection methods can select **different features for each group** when using `per_group_prep=True`. This is powerful for grouped data where different variables may be important for different groups.
#
# We'll demonstrate:
# 1. **step_select_permutation()** - Permutation importance-based selection
# 2. **step_select_shap()** - SHAP value-based selection
# 3. **step_safe_v2()** - SAFE feature engineering + selection
# 4. **step_filter_rf_importance()** - Random Forest importance filtering
#
# **Key Point**: With `per_group_prep=True`, each group's recipe will select features independently based on that group's data patterns.

# %%
# Import feature selection steps
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

print("✓ Feature selection imports complete")
# Out:
# ✓ Feature selection imports complete

# %%
# train_data_r = train_data.rename(columns={"refinery_kbd":'target'})
# train_data_r = train_data.rename(columns={"refinery_kbd":'target'})
# display(train_data_r.head(10))

# %% [markdown]
# ## 1. Permutation Importance Feature Selection
#
# `step_select_permutation()` uses permutation importance to rank features by how much model performance degrades when that feature is shuffled.
#
# **How it works with grouped data**:
# - Each group's recipe fits a model on that group's training data
# - Calculates permutation importance for each feature
# - Selects top features based on `top_n` or `top_p` threshold
# - Different groups may select different features

# %%
# Create recipe with permutation importance feature selection
rec_perm = (
    recipe()
    .step_normalize()  # Normalize first
    .step_select_permutation(
        outcome='refinery_kbd',
        model=RandomForestRegressor(n_estimators=50, random_state=42),
        top_n=3,  # Select top 3 features per group
        n_repeats=5,  # Repeat permutation 5 times for stability
        random_state=42
    )
)

# Create workflow
wf_perm = (
    workflow()
    .add_recipe(rec_perm)
    .add_model(linear_reg().set_engine("sklearn"))
    .add_model_name("permutation_selection")
    .add_model_group_name("feature_selection_models")
)

# Fit with per-group preprocessing
print("Fitting model with permutation importance feature selection...")
fit_perm = wf_perm.fit_nested(train_data, group_col='country')
fit_perm = fit_perm.evaluate(test_data)

print("\n✓ Permutation importance model fitted successfully!")

fit = fit_perm

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Create recipe with permutation importance feature selection
#       2 rec_perm = (
# ----> 3     recipe()
#       4     .step_normalize()  # Normalize first
#       5     .step_select_permutation(
#       6         outcome='refinery_kbd',
#       7         model=RandomForestRegressor(n_estimators=50, random_state=42),
#       8         top_n=3,  # Select top 3 features per group
#       9         n_repeats=5,  # Repeat permutation 5 times for stability
#      10         random_state=42
#      11     )
#      12 )
#      14 # Create workflow
#      15 wf_perm = (
#      16     workflow()
#      17     .add_recipe(rec_perm)
#    (...)
#      20     .add_model_group_name("feature_selection_models")
#      21 )
#
# File ~/Documents/Data Science/python/_projects/py-tidymodels/py_recipes/recipe.py:930, in Recipe.step_select_permutation(self, outcome, model, threshold, top_n, top_p, n_repeats, scoring, random_state, n_jobs)
#     886 def step_select_permutation(
#     887     self,
#     888     outcome: str,
#    (...)
#     896     n_jobs: int = -1
#     897 ) -> "Recipe":
#     898     """
#     899     Filter features using permutation importance.
#     900
#    (...)
#     928         Parallel execution recommended for large datasets.
#     929     """
# --> 930     from py_recipes.steps.filter_supervised import StepSelectPermutation
#     931     return self.add_step(StepSelectPermutation(
#     932         outcome=outcome, model=model, threshold=threshold, top_n=top_n,
#     933         top_p=top_p, n_repeats=n_repeats, scoring=scoring,
#     934         random_state=random_state, n_jobs=n_jobs
#     935     ))
#
# ImportError: cannot import name 'StepSelectPermutation' from 'py_recipes.steps.filter_supervised' (/Users/matthewdeane/Documents/Data Science/python/_projects/py-tidymodels/py_recipes/steps/filter_supervised.py)

# %% [markdown]
# ## 2. SHAP Value Feature Selection
#
# `step_select_shap()` uses SHAP (SHapley Additive exPlanations) values to determine feature importance based on game theory.
#
# **How it works with grouped data**:
# - Each group's recipe fits a model and calculates SHAP values
# - Features are ranked by mean absolute SHAP value
# - Top features are selected based on `top_n`, `top_p`, or `threshold`
# - Groups may identify different important features

# %%
# Create recipe with SHAP-based feature selection
rec_shap = (
    recipe()
    .step_normalize()  # Normalize first
    .step_select_shap(
        outcome='refinery_kbd',
        model=GradientBoostingRegressor(n_estimators=50, random_state=42),
        top_n=4,  # Select top 4 features per group
        shap_samples=100,  # Use 100 samples for SHAP calculation (faster)
        random_state=42
    )
)

# Create workflow
wf_shap = (
    workflow()
    .add_recipe(rec_shap)
    .add_model(linear_reg().set_engine("sklearn"))
    .add_model_name("shap_selection")
    .add_model_group_name("feature_selection_models")
)

# Fit with per-group preprocessing
print("Fitting model with SHAP-based feature selection...")
fit_shap = wf_shap.fit_nested(train_data, group_col='country')
fit_shap = fit_shap.evaluate(test_data)

print("\n✓ SHAP-based model fitted successfully!")

fit = fit_shap

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 3
#       1 # Create recipe with SHAP-based feature selection
#       2 rec_shap = (
# ----> 3     recipe()
#       4     .step_normalize()  # Normalize first
#       5     .step_select_shap(
#       6         outcome='refinery_kbd',
#       7         model=GradientBoostingRegressor(n_estimators=50, random_state=42),
#       8         top_n=4,  # Select top 4 features per group
#       9         shap_samples=100,  # Use 100 samples for SHAP calculation (faster)
#      10         random_state=42
#      11     )
#      12 )
#      14 # Create workflow
#      15 wf_shap = (
#      16     workflow()
#      17     .add_recipe(rec_shap)
#    (...)
#      20     .add_model_group_name("feature_selection_models")
#      21 )
#
# File ~/Documents/Data Science/python/_projects/py-tidymodels/py_recipes/recipe.py:880, in Recipe.step_select_shap(self, outcome, model, threshold, top_n, top_p, shap_samples, random_state)
#     841 def step_select_shap(
#     842     self,
#     843     outcome: str,
#    (...)
#     849     random_state: Optional[int] = None
#     850 ) -> "Recipe":
#     851     """
#     852     Filter features using SHAP (SHapley Additive exPlanations) values.
#     853
#    (...)
#     878         Requires shap package: pip install shap
#     879     """
# --> 880     from py_recipes.steps.filter_supervised import StepSelectShap
#     881     return self.add_step(StepSelectShap(
#     882         outcome=outcome, model=model, threshold=threshold, top_n=top_n,
#     883         top_p=top_p, shap_samples=shap_samples, random_state=random_state
#     884     ))
#
# ImportError: cannot import name 'StepSelectShap' from 'py_recipes.steps.filter_supervised' (/Users/matthewdeane/Documents/Data Science/python/_projects/py-tidymodels/py_recipes/steps/filter_supervised.py)

# %% [markdown]
# ## 3. SAFE Feature Engineering + Selection
#
# `step_safe_v2()` performs **Surrogate Assisted Feature Extraction** - it creates interpretable transformations of features (thresholds, bins) and selects the most important ones.
#
# **How it works with grouped data**:
# - Each group's recipe fits a surrogate model
# - Creates partial dependence plots to find optimal feature thresholds
# - Generates binary features based on thresholds (e.g., `brent_gt_50`, `wti_lt_70`)
# - Selects top transformed features based on importance
# - Different groups may have different thresholds and transformations
#
# **Note**: SAFE is computationally intensive, so we use `top_n` to limit features.

# %%
# Create recipe with SAFE v2 feature engineering + selection
rec_safe = (
    recipe()
    .step_normalize()  # Normalize first
    .step_safe_v2(
        surrogate_model=GradientBoostingRegressor(n_estimators=50, random_state=42),
        outcome='refinery_kbd',
        penalty=10.0,  # Changepoint penalty (higher = fewer thresholds)
        top_n=5,  # Select top 5 transformed features per group
        max_thresholds=3,  # Max 3 thresholds per feature
        keep_original_cols=False,  # Only keep transformed features
        feature_type='numeric'  # Only numeric features
    )
)

# Create workflow
wf_safe = (
    workflow()
    .add_recipe(rec_safe)
    .add_model(linear_reg().set_engine("sklearn"))
    .add_model_name("safe_selection")
    .add_model_group_name("feature_selection_models")
)

# Fit with per-group preprocessing
print("Fitting model with SAFE feature engineering + selection...")
print("(This may take a minute due to PDP calculations)")
fit_safe = wf_safe.fit_nested(train_data, group_col='country')
fit_safe = fit_safe.evaluate(test_data)

print("\n✓ SAFE-based model fitted successfully!")

fit = fit_safe

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# Fitting model with SAFE feature engineering + selection...
# (This may take a minute due to PDP calculations)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 29
#      27 print("(This may take a minute due to PDP calculations)")
#      28 fit_safe = wf_safe.fit_nested(train_data, group_col='country')
# ---> 29 fit_safe = fit_safe.evaluate(test_data)
#      31 print("\n✓ SAFE-based model fitted successfully!")
#      33 fit = fit_safe
#
# File ~/Documents/Data Science/python/_projects/py-tidymodels/py_workflows/workflow.py:1314, in NestedWorkflowFit.evaluate(self, test_data, outcome_col)
#    1311         group_data_no_group = group_data.drop(columns=[self.group_col])
#    1313     # Evaluate this group's model
# -> 1314     self.group_fits[group] = group_fit.evaluate(group_data_no_group, outcome_col)
#    1316 return self
#
# File ~/Documents/Data Science/python/_projects/py-tidymodels/py_workflows/workflow.py:981, in WorkflowFit.evaluate(self, test_data, outcome_col)
#     977     raise ValueError(f"Unknown preprocessor type: {type(self.pre)}")
#     979 # Delegate to the underlying ModelFit with both original and preprocessed data
#     980 # Pass original test data so engines can access raw datetime/categorical values
# --> 981 self.fit = self.fit.evaluate(processed_test_data, outcome_col, original_test_data=test_data)
#     982 return self
#
# File ~/Documents/Data Science/python/_projects/py-tidymodels/py_parsnip/model_spec.py:606, in ModelFit.evaluate(self, test_data, outcome_col, original_test_data)
#     603     pred_type = "numeric"
#     605 # Make predictions on test data
# --> 606 predictions = self.predict(test_data, type=pred_type)
#     608 # Store evaluation results (including original test data for raw values)
#     609 self.evaluation_data["test_data"] = test_data
#
# File ~/Documents/Data Science/python/_projects/py-tidymodels/py_parsnip/model_spec.py:531, in ModelFit.predict(self, new_data, type)
#     528     predictions = engine.predict_raw(self, new_data, type=type)
#     529 else:
#     530     # Standard forging path
# --> 531     forged = forge(new_data, self.blueprint)
#     532     predictions = engine.predict(self, forged, type=type)
#     534 return predictions
#
# File ~/Documents/Data Science/python/_projects/py-tidymodels/py_hardhat/forge.py:73, in forge(new_data, blueprint, outcomes)
#      70 _validate_factor_levels(new_data, blueprint)
#      72 # Validate required columns are present
# ---> 73 _validate_columns(new_data, blueprint)
#      75 # Create design matrix using stored design info for consistency
#      76 try:
#      77     # Use patsy's build_design_matrices with stored design_info
#      78     # This ensures identical structure even if some categorical levels are missing
#
# File ~/Documents/Data Science/python/_projects/py-tidymodels/py_hardhat/forge.py:208, in _validate_columns(data, blueprint)
#     206 missing_cols = required_cols - set(data.columns)
#     207 if missing_cols:
# --> 208     raise ValueError(
#     209         f"Required base columns missing from new_data: {missing_cols}. "
#     210         f"Available columns: {list(data.columns)}"
#     211     )
#
# ValueError: Required base columns missing from new_data: {'bakken_coking_usmc_gt_1_57', 'urals_cracking_med_gt_0_16', 'x50_50_hls_lls_cracking_usgc_gt_0_17'}. Available columns: ['x50_50_hls_lls_cracking_usgc_gt_0_29', 'urals_cracking_med_gt_0_96', 'urals_cracking_med_gt_0_20', 'refinery_kbd']

# %% [markdown]
# ## 4. Random Forest Importance Feature Selection
#
# `step_filter_rf_importance()` uses Random Forest's built-in feature importance (mean decrease in impurity) to select features.
#
# **How it works with grouped data**:
# - Each group's recipe fits a Random Forest on that group's data
# - Features are ranked by importance scores
# - Top features are selected based on `top_n`, `top_p`, or `threshold`
# - Fast and reliable for initial feature screening

# %%
# Create recipe with RF importance feature selection
rec_rf = (
    recipe()
    .step_normalize(all_numeric_predictors())  # Normalize first
    .step_filter_rf_importance(
        outcome='refinery_kbd',
        top_n=3  # Select top 3 features per group
        # n_estimators=100,  # RF trees
        # random_state=42
    )
)

# Create workflow
wf_rf = (
    workflow()
    .add_recipe(rec_rf)
    .add_model(linear_reg().set_engine("sklearn"))
    .add_model_name("rf_importance_selection")
    .add_model_group_name("feature_selection_models")
)

# Fit with per-group preprocessing
print("Fitting model with RF importance feature selection...")
fit_rf = wf_rf.fit_nested(train_data, group_col='country')
fit_rf = fit_rf.evaluate(test_data)

fit = fit_rf

outputs, coefs, stats = fit.extract_outputs()

display(outputs)
display(coefs)
display(stats)

# Plot forecast
fig = plot_forecast(fit, title="Complex Recipe")
fig.show()

# Extract preprocessed training data
processed_train = fit.extract_preprocessed_data(train_data, split='train')
processed_test = fit.extract_preprocessed_data(test_data, split='test')    

display(processed_train.tail(10))
display(processed_test.head(10))

display(fit.get_feature_comparison())
# Out:
# Fitting model with RF importance feature selection...
#            date         country   actuals    fitted  forecast  residuals  \
# 0    2006-01-01         Algeria -0.411900  0.266087 -0.411900  -0.677987
# 1    2006-02-01         Algeria -0.554261  0.380608 -0.554261  -0.934869
# 2    2006-03-01         Algeria -0.625441  0.047827 -0.625441  -0.673268
# 3    2006-04-01         Algeria -0.401731 -0.243348 -0.401731  -0.158384
# 4    2006-05-01         Algeria -1.235559 -0.167265 -1.235559  -1.068294
# ...         ...             ...       ...       ...       ...        ...
# 1915 2021-08-01  United Kingdom -1.596937 -0.265772 -1.596937  -1.331165
# 1916 2021-09-01  United Kingdom -2.022208 -0.144634 -2.022208  -1.877574
# 1917 2021-10-01  United Kingdom -2.193722  0.200065 -2.193722  -2.393787
# 1918 2021-11-01  United Kingdom -1.539314 -0.124588 -1.539314  -1.414726
# 1919 2021-12-01  United Kingdom -1.574743 -0.144646 -1.574743  -1.430097
#
#       split                    model          model_group_name   group
# 0     train  rf_importance_selection  feature_selection_models  global
# 1     train  rf_importance_selection  feature_selection_models  global
# 2     train  rf_importance_selection  feature_selection_models  global
# 3     train  rf_importance_selection  feature_selection_models  global
# 4     train  rf_importance_selection  feature_selection_models  global
# ...     ...                      ...                       ...     ...
# 1915   test  rf_importance_selection  feature_selection_models  global
# 1916   test  rf_importance_selection  feature_selection_models  global
# 1917   test  rf_importance_selection  feature_selection_models  global
# 1918   test  rf_importance_selection  feature_selection_models  global
# 1919   test  rf_importance_selection  feature_selection_models  global
#
# [1920 rows x 10 columns]
#                country                         variable   coefficient  \
# 0              Algeria                        Intercept -1.260603e-15
# 1              Algeria                            brent -1.421430e+00
# 2              Algeria  x30_70_wcs_bakken_cracking_usmc -2.336333e-01
# 3              Algeria                            dubai  1.316054e+00
# 4              Denmark                        Intercept -1.136175e-15
# 5              Denmark                            dubai  1.437883e+00
# 6              Denmark                            brent -1.499972e+00
# 7              Denmark         urals_cracking_nw_europe  1.697960e-01
# 8              Germany                        Intercept  2.746409e-15
# 9              Germany               urals_cracking_med  4.079545e-01
# 10             Germany                            brent  3.745312e+00
# 11             Germany                            dubai -3.872534e+00
# 12               Italy                        Intercept  2.177077e-15
# 13               Italy                            brent  2.754284e+00
# 14               Italy               urals_cracking_med  3.608307e-01
# 15               Italy                            dubai -2.786536e+00
# 16         Netherlands                        Intercept  1.407146e-15
# 17         Netherlands                            brent  1.352500e-01
# 18         Netherlands                            dubai -1.986513e-01
# 19         Netherlands     x50_50_hls_lls_cracking_usgc  4.112579e-01
# 20              Norway                        Intercept  4.132874e-16
# 21              Norway                            brent  1.288501e+00
# 22              Norway                            dubai -1.276303e+00
# 23              Norway    brent_hydroskimming_nw_europe -1.238993e-01
# 24             Romania                        Intercept  2.085686e-15
# 25             Romania                            dubai -3.006205e+00
# 26             Romania               urals_cracking_med  3.303086e-01
# 27             Romania                            brent  2.760003e+00
# 28  Russian Federation                        Intercept -1.059018e-15
# 29  Russian Federation     x50_50_hls_lls_cracking_usgc  8.315065e-01
# 30  Russian Federation                            dubai  3.103800e-01
# 31  Russian Federation               urals_cracking_med -6.416704e-01
# 32              Turkey                        Intercept  3.429639e-15
# 33              Turkey                            dubai -4.311499e+00
# 34              Turkey                            brent  3.908040e+00
# 35              Turkey            es_sider_cracking_med  4.174847e-01
# 36      United Kingdom                        Intercept -1.179713e-15
# 37      United Kingdom                            brent -8.402175e-01
# 38      United Kingdom               urals_cracking_med  3.096012e-01
# 39      United Kingdom                              wti  1.144038e+00
#
#     std_error        t_stat       p_value         vif  \
# 0    0.080397 -1.567972e-14  1.000000e+00         NaN
# 1    1.213697 -1.171157e+00  2.435251e-01  227.898369
# 2    0.086939 -2.687335e+00  8.075403e-03    1.169355
# 3    1.211503  1.086299e+00  2.792138e-01  227.075019
# 4    0.082709 -1.373704e-14  1.000000e+00         NaN
# 5    1.261384  1.139924e+00  2.562644e-01  232.589999
# 6    1.258174 -1.192182e+00  2.352069e-01  231.407518
# 7    0.086246  1.968749e+00  5.095695e-02    1.087353
# 8    0.070437  3.899111e-14  1.000000e+00         NaN
# 9    0.072885  5.597262e+00  1.109274e-07    1.070713
# 10   1.092689  3.427611e+00  7.998567e-04  240.654418
# 11   1.094076 -3.539546e+00  5.445150e-04  241.265949
# 12   0.075614  2.879194e-14  1.000000e+00         NaN
# 13   1.173005  2.348059e+00  2.027136e-02  240.654418
# 14   0.078242  4.611733e+00  8.919757e-06    1.070713
# 15   1.174494 -2.372542e+00  1.902594e-02  241.265949
# 16   0.075882  1.854381e-14  1.000000e+00         NaN
# 17   1.170467  1.155522e-01  9.081730e-01  237.923689
# 18   1.162949 -1.708168e-01  8.646144e-01  234.877366
# 19   0.085764  4.795237e+00  4.104836e-06    1.277403
# 20   0.083196  4.967657e-15  1.000000e+00         NaN
# 21   1.348428  9.555579e-01  3.409427e-01  262.696602
# 22   1.337757 -9.540618e-01  3.416968e-01  258.555312
# 23   0.093994 -1.318167e+00  1.896003e-01    1.276426
# 24   0.073191  2.849643e-14  1.000000e+00         NaN
# 25   1.136858 -2.644309e+00  9.120224e-03  241.265949
# 26   0.075735  4.361392e+00  2.489062e-05    1.070713
# 27   1.135417  2.430828e+00  1.632926e-02  240.654418
# 28   0.051116 -2.071793e-14  1.000000e+00         NaN
# 29   0.060315  1.378604e+01  0.000000e+00    1.392318
# 30   0.056526  5.490917e+00  1.825406e-07    1.222879
# 31   0.054906 -1.168669e+01  0.000000e+00    1.153791
# 32   0.062491  5.488199e-14  1.000000e+00         NaN
# 33   0.940719 -4.583193e+00  1.004612e-05  226.612052
# 34   0.940547  4.155070e+00  5.631358e-05  226.529124
# 35   0.062870  6.640467e+00  6.383940e-10    1.012154
# 36   0.071385 -1.652601e-14  1.000000e+00         NaN
# 37   0.301531 -2.786505e+00  6.067593e-03   17.842147
# 38   0.074674  4.146024e+00  5.832959e-05    1.094271
# 39   0.300809  3.803207e+00  2.126025e-04   17.756778
#
#                       model          model_group_name   group  ci_0.025  \
# 0   rf_importance_selection  feature_selection_models  global -0.158949
# 1   rf_importance_selection  feature_selection_models  global -3.820975
# 2   rf_importance_selection  feature_selection_models  global -0.405516
# 3   rf_importance_selection  feature_selection_models  global -1.079152
# 4   rf_importance_selection  feature_selection_models  global -0.163520
# 5   rf_importance_selection  feature_selection_models  global -1.055942
# 6   rf_importance_selection  feature_selection_models  global -3.987449
# 7   rf_importance_selection  feature_selection_models  global -0.000716
# 8   rf_importance_selection  feature_selection_models  global -0.139257
# 9   rf_importance_selection  feature_selection_models  global  0.263858
# 10  rf_importance_selection  feature_selection_models  global  1.585008
# 11  rf_importance_selection  feature_selection_models  global -6.035581
# 12  rf_importance_selection  feature_selection_models  global -0.149493
# 13  rf_importance_selection  feature_selection_models  global  0.435191
# 14  rf_importance_selection  feature_selection_models  global  0.206142
# 15  rf_importance_selection  feature_selection_models  global -5.108574
# 16  rf_importance_selection  feature_selection_models  global -0.150023
# 17  rf_importance_selection  feature_selection_models  global -2.178825
# 18  rf_importance_selection  feature_selection_models  global -2.497864
# 19  rf_importance_selection  feature_selection_models  global  0.241698
# 20  rf_importance_selection  feature_selection_models  global -0.164482
# 21  rf_importance_selection  feature_selection_models  global -1.377414
# 22  rf_importance_selection  feature_selection_models  global -3.921121
# 23  rf_importance_selection  feature_selection_models  global -0.309730
# 24  rf_importance_selection  feature_selection_models  global -0.144703
# 25  rf_importance_selection  feature_selection_models  global -5.253836
# 26  rf_importance_selection  feature_selection_models  global  0.180577
# 27  rf_importance_selection  feature_selection_models  global  0.515223
# 28  rf_importance_selection  feature_selection_models  global -0.101059
# 29  rf_importance_selection  feature_selection_models  global  0.712260
# 30  rf_importance_selection  feature_selection_models  global  0.198625
# 31  rf_importance_selection  feature_selection_models  global -0.750223
# 32  rf_importance_selection  feature_selection_models  global -0.123548
# 33  rf_importance_selection  feature_selection_models  global -6.171352
# 34  rf_importance_selection  feature_selection_models  global  2.048528
# 35  rf_importance_selection  feature_selection_models  global  0.293188
# 36  rf_importance_selection  feature_selection_models  global -0.141132
# 37  rf_importance_selection  feature_selection_models  global -1.436360
# 38  rf_importance_selection  feature_selection_models  global  0.161966
# 39  rf_importance_selection  feature_selection_models  global  0.549323
#
#     ci_0.975
# 0   0.158949
# 1   0.978114
# 2  -0.061751
# 3   3.711260
# 4   0.163520
# 5   3.931707
# 6   0.987505
# 7   0.340308
# 8   0.139257
# 9   0.552051
# 10  5.905617
# 11 -1.709486
# 12  0.149493
# 13  5.073377
# 14  0.515519
# 15 -0.464499
# 16  0.150023
# 17  2.449325
# 18  2.100562
# 19  0.580818
# 20  0.164482
# 21  3.954416
# 22  1.368515
# 23  0.061931
# 24  0.144703
# 25 -0.758575
# 26  0.480040
# 27  5.004783
# 28  0.101059
# 29  0.950753
# 30  0.422135
# 31 -0.533118
# 32  0.123548
# 33 -2.451646
# 34  5.767553
# 35  0.541782
# 36  0.141132
# 37 -0.244075
# 38  0.457236
# 39  1.738753
#             country  split            metric                          value  \
# 0           Algeria  train              rmse                        0.95127
# 1           Algeria  train               mae                       0.714182
# 2           Algeria  train              mape                     370.344744
# 3           Algeria  train             smape                     149.718879
# 4           Algeria  train         r_squared                       0.095086
# ..              ...    ...               ...                            ...
# 255  United Kingdom               model_type                     linear_reg
# 256  United Kingdom              model_class               LinearRegression
# 257  United Kingdom  train       n_obs_train                            144
# 258  United Kingdom  train  train_start_date  2006-01-01T00:00:00.000000000
# 259  United Kingdom  train    train_end_date  2017-12-01T00:00:00.000000000
#
#                        model          model_group_name   group
# 0    rf_importance_selection  feature_selection_models  global
# 1    rf_importance_selection  feature_selection_models  global
# 2    rf_importance_selection  feature_selection_models  global
# 3    rf_importance_selection  feature_selection_models  global
# 4    rf_importance_selection  feature_selection_models  global
# ..                       ...                       ...     ...
# 255  rf_importance_selection  feature_selection_models  global
# 256  rf_importance_selection  feature_selection_models  global
# 257  rf_importance_selection  feature_selection_models  global
# 258  rf_importance_selection  feature_selection_models  global
# 259  rf_importance_selection  feature_selection_models  global
#
# [260 rows x 7 columns]
#            date         country     brent  x30_70_wcs_bakken_cracking_usmc  \
# 1430 2017-03-01  United Kingdom -1.057443                              NaN
# 1431 2017-04-01  United Kingdom -1.019196                              NaN
# 1432 2017-05-01  United Kingdom -1.099098                              NaN
# 1433 2017-06-01  United Kingdom -1.249813                              NaN
# 1434 2017-07-01  United Kingdom -1.181650                              NaN
# 1435 2017-08-01  United Kingdom -1.080163                              NaN
# 1436 2017-09-01  United Kingdom -0.936643                              NaN
# 1437 2017-10-01  United Kingdom -0.843487                              NaN
# 1438 2017-11-01  United Kingdom -0.656040                              NaN
# 1439 2017-12-01  United Kingdom -0.593936                              NaN
#
#       dubai  refinery_kbd  urals_cracking_nw_europe  urals_cracking_med  \
# 1430    NaN     -1.261554                       NaN           -0.131079
# 1431    NaN     -1.144334                       NaN            0.158431
# 1432    NaN     -1.325671                       NaN            0.058354
# 1433    NaN     -1.069161                       NaN            0.133412
# 1434    NaN     -1.268952                       NaN            0.340715
# 1435    NaN     -0.969327                       NaN            0.433644
# 1436    NaN     -0.972327                       NaN            0.912586
# 1437    NaN     -1.138251                       NaN            0.144134
# 1438    NaN     -1.420820                       NaN           -0.356253
# 1439    NaN     -1.329370                       NaN           -0.677930
#
#       x50_50_hls_lls_cracking_usgc  brent_hydroskimming_nw_europe  \
# 1430                           NaN                            NaN
# 1431                           NaN                            NaN
# 1432                           NaN                            NaN
# 1433                           NaN                            NaN
# 1434                           NaN                            NaN
# 1435                           NaN                            NaN
# 1436                           NaN                            NaN
# 1437                           NaN                            NaN
# 1438                           NaN                            NaN
# 1439                           NaN                            NaN
#
#       es_sider_cracking_med       wti  split
# 1430                    NaN -1.112604  train
# 1431                    NaN -1.048256  train
# 1432                    NaN -1.159561  train
# 1433                    NaN -1.304345  train
# 1434                    NaN -1.239997  train
# 1435                    NaN -1.179996  train
# 1436                    NaN -1.101735  train
# 1437                    NaN -1.026517  train
# 1438                    NaN -0.805211  train
# 1439                    NaN -0.749124  train
#         date  country     brent  x30_70_wcs_bakken_cracking_usmc     dubai  \
# 0 2018-01-01  Algeria -0.412926                        -0.184520 -0.434697
# 1 2018-02-01  Algeria -0.548116                        -0.622057 -0.560742
# 2 2018-03-01  Algeria -0.509111                        -0.448739 -0.541230
# 3 2018-04-01  Algeria -0.312954                        -0.002719 -0.340651
# 4 2018-05-01  Algeria -0.122856                         0.571775 -0.136559
# 5 2018-06-01  Algeria -0.178143                         0.436030 -0.153730
# 6 2018-07-01  Algeria -0.206545                         0.188779 -0.173241
# 7 2018-08-01  Algeria -0.256152                         0.460270 -0.196265
# 8 2018-09-01  Algeria -0.039167                         0.443302 -0.005442
# 9 2018-10-01  Algeria  0.021800                         0.021522  0.070263
#
#    refinery_kbd  urals_cracking_nw_europe  urals_cracking_med  \
# 0      0.798167                       NaN                 NaN
# 1      1.123563                       NaN                 NaN
# 2      1.235418                       NaN                 NaN
# 3      1.520140                       NaN                 NaN
# 4      0.289735                       NaN                 NaN
# 5      0.198218                       NaN                 NaN
# 6     -0.615273                       NaN                 NaN
# 7      1.418453                       NaN                 NaN
# 8      1.784524                       NaN                 NaN
# 9      1.225249                       NaN                 NaN
#
#    x50_50_hls_lls_cracking_usgc  brent_hydroskimming_nw_europe  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
# 5                           NaN                            NaN
# 6                           NaN                            NaN
# 7                           NaN                            NaN
# 8                           NaN                            NaN
# 9                           NaN                            NaN
#
#    es_sider_cracking_med  wti split
# 0                    NaN  NaN  test
# 1                    NaN  NaN  test
# 2                    NaN  NaN  test
# 3                    NaN  NaN  test
# 4                    NaN  NaN  test
# 5                    NaN  NaN  test
# 6                    NaN  NaN  test
# 7                    NaN  NaN  test
# 8                    NaN  NaN  test
# 9                    NaN  NaN  test
#                     brent  brent_hydroskimming_nw_europe  dubai  \
# Algeria              True                          False   True
# Denmark              True                          False   True
# Germany              True                          False   True
# Italy                True                          False   True
# Netherlands          True                          False   True
# Norway               True                           True   True
# Romania              True                          False   True
# Russian Federation  False                          False   True
# Turkey               True                          False   True
# United Kingdom       True                          False  False
#
#                     es_sider_cracking_med  urals_cracking_med  \
# Algeria                             False               False
# Denmark                             False               False
# Germany                             False                True
# Italy                               False                True
# Netherlands                         False               False
# Norway                              False               False
# Romania                             False                True
# Russian Federation                  False                True
# Turkey                               True               False
# United Kingdom                      False                True
#
#                     urals_cracking_nw_europe    wti  \
# Algeria                                False  False
# Denmark                                 True  False
# Germany                                False  False
# Italy                                  False  False
# Netherlands                            False  False
# Norway                                 False  False
# Romania                                False  False
# Russian Federation                     False  False
# Turkey                                 False  False
# United Kingdom                         False   True
#
#                     x30_70_wcs_bakken_cracking_usmc  \
# Algeria                                        True
# Denmark                                       False
# Germany                                       False
# Italy                                         False
# Netherlands                                   False
# Norway                                        False
# Romania                                       False
# Russian Federation                            False
# Turkey                                        False
# United Kingdom                                False
#
#                     x50_50_hls_lls_cracking_usgc
# Algeria                                    False
# Denmark                                    False
# Germany                                    False
# Italy                                      False
# Netherlands                                 True
# Norway                                     False
# Romania                                    False
# Russian Federation                          True
# Turkey                                     False
# United Kingdom                             False

# %% [markdown]
# ## Comparison of Feature Selection Methods
#
# Let's compare how different feature selection methods performed and what features they selected for each group.

# %% [markdown]
# ## Key Takeaways
#
# ### Per-Group Feature Selection Benefits
#
# 1. **Adaptive to Group Patterns**: Each group selects features most relevant to its data
# 2. **Improved Interpretability**: Different groups may have different drivers
# 3. **Better Performance**: Group-specific features can improve accuracy
#
# ### Method Selection Guide
#
# | Method | Speed | Interpretability | Best For |
# |--------|-------|------------------|----------|
# | **step_filter_rf_importance()** | ⚡⚡⚡ Fast | ⭐⭐ Good | Initial screening, high-dimensional data |
# | **step_select_permutation()** | ⚡⚡ Medium | ⭐⭐⭐ Very Good | Model-agnostic importance, any model type |
# | **step_select_shap()** | ⚡ Slow | ⭐⭐⭐ Very Good | Detailed explanations, tree-based models |
# | **step_safe_v2()** | 🐌 Very Slow | ⭐⭐⭐⭐ Excellent | Interpretable rules, threshold discovery |
#
# ### Recommendations
#
# 1. **Start with RF importance** for quick screening
# 2. **Use permutation importance** for robust, model-agnostic selection
# 3. **Use SHAP** for detailed explanations and feature interactions
# 4. **Use SAFE** when you need interpretable thresholds and rules
#
# ### Next Steps
#
# - Try combining multiple selection methods in sequence
# - Experiment with different `top_n` values per group
# - Compare per-group vs shared preprocessing performance
# - Use `.extract_preprocessed_data()` to inspect selected features
